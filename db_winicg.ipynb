-- %% [markdown]
-- # [db_winicg]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [db_winicg]    Script Date: 4/3/2024 8:42:49 PM ******/
CREATE DATABASE [db_winicg]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'db_winicg', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.SQLEXPRESS\MSSQL\DATA\db_winicg.mdf' , SIZE = 8192KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'db_winicg_log', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.SQLEXPRESS\MSSQL\DATA\db_winicg_log.ldf' , SIZE = 8192KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
 WITH CATALOG_COLLATION = DATABASE_DEFAULT, LEDGER = OFF
GO
ALTER DATABASE [db_winicg] SET COMPATIBILITY_LEVEL = 160
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [db_winicg].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [db_winicg] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [db_winicg] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [db_winicg] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [db_winicg] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [db_winicg] SET ARITHABORT OFF 
GO
ALTER DATABASE [db_winicg] SET AUTO_CLOSE ON 
GO
ALTER DATABASE [db_winicg] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [db_winicg] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [db_winicg] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [db_winicg] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [db_winicg] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [db_winicg] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [db_winicg] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [db_winicg] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [db_winicg] SET  ENABLE_BROKER 
GO
ALTER DATABASE [db_winicg] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [db_winicg] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [db_winicg] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [db_winicg] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [db_winicg] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [db_winicg] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [db_winicg] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [db_winicg] SET RECOVERY SIMPLE 
GO
ALTER DATABASE [db_winicg] SET  MULTI_USER 
GO
ALTER DATABASE [db_winicg] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [db_winicg] SET DB_CHAINING OFF 
GO
ALTER DATABASE [db_winicg] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [db_winicg] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [db_winicg] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [db_winicg] SET ACCELERATED_DATABASE_RECOVERY = OFF  
GO
ALTER DATABASE [db_winicg] SET QUERY_STORE = ON
GO
ALTER DATABASE [db_winicg] SET QUERY_STORE (OPERATION_MODE = READ_WRITE, CLEANUP_POLICY = (STALE_QUERY_THRESHOLD_DAYS = 30), DATA_FLUSH_INTERVAL_SECONDS = 900, INTERVAL_LENGTH_MINUTES = 60, MAX_STORAGE_SIZE_MB = 1000, QUERY_CAPTURE_MODE = AUTO, SIZE_BASED_CLEANUP_MODE = AUTO, MAX_PLANS_PER_QUERY = 200, WAIT_STATS_CAPTURE_MODE = ON)
GO

-- %% [markdown]
-- # [AUD]

-- %%
USE [db_winicg]
GO

-- %%
/****** Object:  Schema [AUD]    Script Date: 4/3/2024 8:42:49 PM ******/
CREATE SCHEMA [AUD]
GO

-- %% [markdown]
-- # [HIS]

-- %%
/****** Object:  Schema [HIS]    Script Date: 4/3/2024 8:42:49 PM ******/
CREATE SCHEMA [HIS]
GO

-- %% [markdown]
-- # [ISO]

-- %%
/****** Object:  Schema [ISO]    Script Date: 4/3/2024 8:42:49 PM ******/
CREATE SCHEMA [ISO]
GO

-- %% [markdown]
-- # [ORG]

-- %%
/****** Object:  Schema [ORG]    Script Date: 4/3/2024 8:42:49 PM ******/
CREATE SCHEMA [ORG]
GO

-- %% [markdown]
-- # [PRO]

-- %%
/****** Object:  Schema [PRO]    Script Date: 4/3/2024 8:42:49 PM ******/
CREATE SCHEMA [PRO]
GO

-- %% [markdown]
-- # [US]

-- %%
/****** Object:  Schema [US]    Script Date: 4/3/2024 8:42:49 PM ******/
CREATE SCHEMA [US]
GO

-- %% [markdown]
-- # [AUD].[GET_CODE_FILES]

-- %%
/****** Object:  UserDefinedFunction [AUD].[GET_CODE_FILES]    Script Date: 4/3/2024 8:42:49 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE FUNCTION [AUD].[GET_CODE_FILES] (@COUNTER INT)
RETURNS  VARCHAR(15)
AS
BEGIN
DECLARE @IDFILES VARCHAR(15)
IF(@COUNTER<10)
	BEGIN
            SET @IDFILES = 'F00'+CAST(@COUNTER AS VARCHAR);
		 END
            ELSE IF (@COUNTER <100) 
			BEGIN
                SET @IDFILES='F0'+CAST(@COUNTER AS VARCHAR);
			END
                ELSE IF(@COUNTER <1000)
				BEGIN
                    SET @IDFILES= CONCAT('F',CAST(@COUNTER AS VARCHAR));
                END
		RETURN @IDFILES;
END;
GO

-- %% [markdown]
-- # [ISO].[GET_CODE_AUDIT]

-- %%
/****** Object:  UserDefinedFunction [ISO].[GET_CODE_AUDIT]    Script Date: 4/3/2024 8:42:49 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE FUNCTION [ISO].[GET_CODE_AUDIT] (@COUNTER INT)
RETURNS  VARCHAR(15)
AS
BEGIN
DECLARE @IDAUDIT VARCHAR(15)
IF(@COUNTER<10)
	BEGIN
            SET @IDAUDIT = 'A00'+CAST(@COUNTER AS VARCHAR);
		 END
            ELSE IF (@COUNTER <100) 
			BEGIN
                SET @IDAUDIT='A0'+CAST(@COUNTER AS VARCHAR);
			END
                ELSE IF(@COUNTER <1000)
				BEGIN
                    SET @IDAUDIT= CONCAT('A',CAST(@COUNTER AS VARCHAR));
                END
		RETURN @IDAUDIT;
END;
GO

-- %% [markdown]
-- # [ISO].[GET_CODE_CERTIFICATION]

-- %%
/****** Object:  UserDefinedFunction [ISO].[GET_CODE_CERTIFICATION]    Script Date: 4/3/2024 8:42:49 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE FUNCTION [ISO].[GET_CODE_CERTIFICATION] (@COUNTER INT)
RETURNS  VARCHAR(15)
AS
BEGIN
DECLARE @IDCERTIFICATION VARCHAR(15)
IF(@COUNTER<10)
	BEGIN
            SET @IDCERTIFICATION = 'C00'+CAST(@COUNTER AS VARCHAR);
		 END
            ELSE IF (@COUNTER <100) 
			BEGIN
                SET @IDCERTIFICATION='C0'+CAST(@COUNTER AS VARCHAR);
			END
                ELSE IF(@COUNTER <1000)
				BEGIN
                    SET @IDCERTIFICATION= CONCAT('C',CAST(@COUNTER AS VARCHAR));
                END
		RETURN @IDCERTIFICATION;
END;
GO

-- %% [markdown]
-- # [ISO].[GET_CODE_FLAG]

-- %%
/****** Object:  UserDefinedFunction [ISO].[GET_CODE_FLAG]    Script Date: 4/3/2024 8:42:49 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE FUNCTION [ISO].[GET_CODE_FLAG] (@COUNTER INT)
RETURNS  VARCHAR(15)
AS
BEGIN
DECLARE @IDFALG VARCHAR(15)
IF(@COUNTER<10)
	BEGIN
            SET @IDFALG = 'F00'+CAST(@COUNTER AS VARCHAR);
		 END
            ELSE IF (@COUNTER <100) 
			BEGIN
                SET @IDFALG='F0'+CAST(@COUNTER AS VARCHAR);
			END
                ELSE IF(@COUNTER <1000)
				BEGIN
                    SET @IDFALG= CONCAT('F',CAST(@COUNTER AS VARCHAR));
                END
		RETURN @IDFALG;
END;
GO

-- %% [markdown]
-- # [ISO].[GET_CODE_ISORULE]

-- %%
/****** Object:  UserDefinedFunction [ISO].[GET_CODE_ISORULE]    Script Date: 4/3/2024 8:42:49 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE FUNCTION [ISO].[GET_CODE_ISORULE] (@COUNTER INT)
RETURNS  VARCHAR(15)
AS
BEGIN
DECLARE @IDISORULE VARCHAR(15)
IF(@COUNTER<10)
	BEGIN
            SET @IDISORULE = 'IS00'+CAST(@COUNTER AS VARCHAR);
		 END
            ELSE IF (@COUNTER <100) 
			BEGIN
                SET @IDISORULE='IS0'+CAST(@COUNTER AS VARCHAR);
			END
                ELSE IF(@COUNTER <1000)
				BEGIN
                    SET @IDISORULE= CONCAT('IS',CAST(@COUNTER AS VARCHAR));
                END
		RETURN @IDISORULE;
END;
GO

-- %% [markdown]
-- # [ISO].[GET_CODE_RISKS]

-- %%
/****** Object:  UserDefinedFunction [ISO].[GET_CODE_RISKS]    Script Date: 4/3/2024 8:42:49 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE FUNCTION [ISO].[GET_CODE_RISKS] (@COUNTER INT)
RETURNS  VARCHAR(15)
AS
BEGIN
DECLARE @IDRISKS VARCHAR(15)
IF(@COUNTER<10)
	BEGIN
            SET @IDRISKS = 'A00'+CAST(@COUNTER AS VARCHAR);
		 END
            ELSE IF (@COUNTER <100) 
			BEGIN
                SET @IDRISKS='A0'+CAST(@COUNTER AS VARCHAR);
			END
                ELSE IF(@COUNTER <1000)
				BEGIN
                    SET @IDRISKS= CONCAT('A',CAST(@COUNTER AS VARCHAR));
                END
		RETURN @IDRISKS;
END;
GO

-- %% [markdown]
-- # [ISO].[GET_CODE_TASK]

-- %%
/****** Object:  UserDefinedFunction [ISO].[GET_CODE_TASK]    Script Date: 4/3/2024 8:42:49 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE FUNCTION [ISO].[GET_CODE_TASK] (@COUNTER INT)
RETURNS  VARCHAR(15)
AS
BEGIN
DECLARE @IDTASK VARCHAR(15)
IF(@COUNTER<10)
	BEGIN
            SET @IDTASK = 'T00'+CAST(@COUNTER AS VARCHAR);
		 END
            ELSE IF (@COUNTER <100) 
			BEGIN
                SET @IDTASK='T0'+CAST(@COUNTER AS VARCHAR);
			END
                ELSE IF(@COUNTER <1000)
				BEGIN
                    SET @IDTASK= CONCAT('T',CAST(@COUNTER AS VARCHAR));
                END
		RETURN @IDTASK;
END;
GO

-- %% [markdown]
-- # [ORG].[GET_CODE_COMPANY]

-- %%
/****** Object:  UserDefinedFunction [ORG].[GET_CODE_COMPANY]    Script Date: 4/3/2024 8:42:49 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE FUNCTION [ORG].[GET_CODE_COMPANY] (@COUNTER INT)
RETURNS  VARCHAR(15)
AS
BEGIN
DECLARE @iIDCOMPANY VARCHAR(15)
IF(@COUNTER<10)
	BEGIN
            SET @iIDCOMPANY = 'CP00'+CAST(@COUNTER AS VARCHAR);
		 END
            ELSE IF (@COUNTER <100) 
			BEGIN
                SET @iIDCOMPANY='CP0'+CAST(@COUNTER AS VARCHAR);
			END
                ELSE IF(@COUNTER <1000)
				BEGIN
                    SET @iIDCOMPANY= CONCAT('CP',CAST(@COUNTER AS VARCHAR));
                END
		RETURN @iIDCOMPANY;
END;
GO

-- %% [markdown]
-- # [PRO].[GET_CODE_NO_ACCORDANCE]

-- %%
/****** Object:  UserDefinedFunction [PRO].[GET_CODE_NO_ACCORDANCE]    Script Date: 4/3/2024 8:42:49 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE FUNCTION [PRO].[GET_CODE_NO_ACCORDANCE] (@COUNTER INT)
RETURNS  VARCHAR(15)
AS
BEGIN
DECLARE @IDNO_ACCORDANCE VARCHAR(15)
IF(@COUNTER<10)
	BEGIN
            SET @IDNO_ACCORDANCE = 'NA00'+CAST(@COUNTER AS VARCHAR);
		 END
            ELSE IF (@COUNTER <100) 
			BEGIN
                SET @IDNO_ACCORDANCE='NA0'+CAST(@COUNTER AS VARCHAR);
			END
                ELSE IF(@COUNTER <1000)
				BEGIN
                    SET @IDNO_ACCORDANCE= CONCAT('NA',CAST(@COUNTER AS VARCHAR));
                END
		RETURN @IDNO_ACCORDANCE;
END;
GO

-- %% [markdown]
-- # [PRO].[GET_CODE_PROCESS]

-- %%
/****** Object:  UserDefinedFunction [PRO].[GET_CODE_PROCESS]    Script Date: 4/3/2024 8:42:49 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE FUNCTION [PRO].[GET_CODE_PROCESS] (@COUNTER INT)
RETURNS  VARCHAR(15)
AS
BEGIN
DECLARE @IDPROCESS VARCHAR(15)
IF(@COUNTER<10)
	BEGIN
            SET @IDPROCESS = 'P00'+CAST(@COUNTER AS VARCHAR);
		 END
            ELSE IF (@COUNTER <100) 
			BEGIN
                SET @IDPROCESS='P0'+CAST(@COUNTER AS VARCHAR);
			END
                ELSE IF(@COUNTER <1000)
				BEGIN
                    SET @IDPROCESS= CONCAT('P',CAST(@COUNTER AS VARCHAR));
                END
		RETURN @IDPROCESS;
END;
GO

-- %% [markdown]
-- # [US].[GET_CODE_POSITION]

-- %%
/****** Object:  UserDefinedFunction [US].[GET_CODE_POSITION]    Script Date: 4/3/2024 8:42:49 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE FUNCTION [US].[GET_CODE_POSITION] (@COUNTER INT)
RETURNS  VARCHAR(15)
AS
BEGIN
DECLARE @IDPOSITION VARCHAR(15)
IF(@COUNTER<10)
	BEGIN
            SET @IDPOSITION = 'P00'+CAST(@COUNTER AS VARCHAR);
		 END
            ELSE IF (@COUNTER <100) 
			BEGIN
                SET @IDPOSITION='P0'+CAST(@COUNTER AS VARCHAR);
			END
                ELSE IF(@COUNTER <1000)
				BEGIN
                    SET @IDPOSITION= CONCAT('P',CAST(@COUNTER AS VARCHAR));
                END
		RETURN @IDPOSITION;
END;
GO

-- %% [markdown]
-- # [US].[GET_CODE_ROLE]

-- %%
/****** Object:  UserDefinedFunction [US].[GET_CODE_ROLE]    Script Date: 4/3/2024 8:42:49 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE FUNCTION [US].[GET_CODE_ROLE] (@COUNTER INT)
RETURNS  VARCHAR(15)
AS
BEGIN
DECLARE @IDROLE VARCHAR(15)
IF(@COUNTER<10)
	BEGIN
            SET @IDROLE = 'R00'+CAST(@COUNTER AS VARCHAR);
		 END
            ELSE IF (@COUNTER <100) 
			BEGIN
                SET @IDROLE='R0'+CAST(@COUNTER AS VARCHAR);
			END
                ELSE IF(@COUNTER <1000)
				BEGIN
                    SET @IDROLE= CONCAT('R',CAST(@COUNTER AS VARCHAR));
                END
		RETURN @IDROLE;
END;
GO

-- %% [markdown]
-- # [US].[GET_CODE_USER]

-- %%
/****** Object:  UserDefinedFunction [US].[GET_CODE_USER]    Script Date: 4/3/2024 8:42:49 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE FUNCTION [US].[GET_CODE_USER] (@COUNTER INT)
RETURNS  VARCHAR(15)
AS
BEGIN
DECLARE @IDUSER VARCHAR(15)
IF(@COUNTER<10)
	BEGIN
            SET @IDUSER = 'U00'+CAST(@COUNTER AS VARCHAR);
		 END
            ELSE IF (@COUNTER <100) 
			BEGIN
                SET @IDUSER='U0'+CAST(@COUNTER AS VARCHAR);
			END
                ELSE IF(@COUNTER <1000)
				BEGIN
                    SET @IDUSER= CONCAT('U',CAST(@COUNTER AS VARCHAR));
                END
		RETURN @IDUSER;
END;
GO

-- %% [markdown]
-- # [AUD].[FILES]

-- %%
/****** Object:  Table [AUD].[FILES]    Script Date: 4/3/2024 8:42:49 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [AUD].[FILES](
	[ID] [int] IDENTITY(1,1) NOT NULL,
	[IDFILE]  AS ('F'+right('00000'+CONVERT([varchar](10),[ID]),(5))) PERSISTED NOT NULL,
	[IDMODULE] [varchar](15) NOT NULL,
	[FILENAME] [varchar](15) NOT NULL,
	[EXTENSION] [varchar](8) NOT NULL,
	[BINARY_FILE] [varbinary](max) NOT NULL,
	[CREATEDATE] [datetime2](7) NULL,
	[UPDATEDATE] [datetime2](7) NULL,
PRIMARY KEY CLUSTERED 
(
	[IDFILE] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [HIS].[HISTORIAL]

-- %%
/****** Object:  Table [HIS].[HISTORIAL]    Script Date: 4/3/2024 8:42:49 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [HIS].[HISTORIAL](
	[IDHISTORIAL] [int] IDENTITY(1,1) NOT NULL,
	[IDMODULE] [varchar](15) NOT NULL,
	[PERSONCHANGE] [varchar](50) NOT NULL,
	[DATEHISTORY] [datetime2](7) NULL,
	[HOUR] [time](6) NULL,
PRIMARY KEY CLUSTERED 
(
	[IDHISTORIAL] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [ISO].[AUDITS]

-- %%
/****** Object:  Table [ISO].[AUDITS]    Script Date: 4/3/2024 8:42:49 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [ISO].[AUDITS](
	[IDAUDIT] [varchar](15) NOT NULL,
	[AUDIT_NAME] [varchar](150) NULL,
	[AUDIT_DATE] [datetime2](7) NULL,
	[AUDIT_TIME] [time](6) NULL,
	[AUDIT_SUBJECT] [varchar](1500) NULL,
	[NUMBER_DAYS] [int] NULL,
	[KIND_AUDIT] [varchar](100) NULL,
	[SCOPE_AUDIT] [varchar](100) NULL,
	[AUDIT_PROCESS] [varchar](100) NULL,
	[AUDIT_RULE] [varchar](50) NULL,
	[PERSONCHANGE] [varchar](50) NULL,
	[CREATEDATE] [datetime2](7) NULL,
	[UPDATEDATE] [datetime2](7) NULL,
PRIMARY KEY CLUSTERED 
(
	[IDAUDIT] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [ISO].[CERTIFICATION]

-- %%
/****** Object:  Table [ISO].[CERTIFICATION]    Script Date: 4/3/2024 8:42:49 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [ISO].[CERTIFICATION](
	[IDCERTIFICATION] [varchar](15) NOT NULL,
	[CERTIFICATION_NAME] [varchar](100) NOT NULL,
	[CERTIFICACION_DATE] [datetime2](7) NULL,
	[PERSONCHANGE] [varchar](50) NULL,
	[CREATEDATE] [datetime2](7) NULL,
	[UPDATEDATE] [datetime2](7) NULL,
PRIMARY KEY CLUSTERED 
(
	[IDCERTIFICATION] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [ISO].[FLAGS]

-- %%
/****** Object:  Table [ISO].[FLAGS]    Script Date: 4/3/2024 8:42:49 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [ISO].[FLAGS](
	[IDFLAG] [varchar](15) NOT NULL,
	[IDRULE] [varchar](15) NOT NULL,
	[FLAGNAME] [varchar](150) NOT NULL,
	[CREATEDATE] [datetime2](7) NULL,
	[UPDATEDATE] [datetime2](7) NULL,
PRIMARY KEY CLUSTERED 
(
	[IDFLAG] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [ISO].[ISORULE]

-- %%
/****** Object:  Table [ISO].[ISORULE]    Script Date: 4/3/2024 8:42:49 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [ISO].[ISORULE](
	[IDRULE] [varchar](15) NOT NULL,
	[IDCERTIFICATION] [varchar](15) NULL,
	[IDAUDIT] [varchar](15) NULL,
	[NAMERULE] [varchar](50) NOT NULL,
	[RULE_DESCRIPTION] [varchar](max) NOT NULL,
	[PERSONCHANGE] [varchar](50) NULL,
	[CREATEDATE] [datetime2](7) NULL,
	[UPDATEDATE] [datetime2](7) NULL,
PRIMARY KEY CLUSTERED 
(
	[IDRULE] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [ISO].[RISKS]

-- %%
/****** Object:  Table [ISO].[RISKS]    Script Date: 4/3/2024 8:42:49 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [ISO].[RISKS](
	[IDRISKS] [varchar](15) NOT NULL,
	[IDRULE] [varchar](15) NOT NULL,
	[NAMERISKS] [varchar](50) NOT NULL,
	[ORIGEN] [varchar](50) NOT NULL,
	[CONSEQUENSE] [varchar](500) NOT NULL,
	[SOURCE_RISK] [varchar](100) NOT NULL,
	[STATE] [bit] NULL,
	[CREATEDATE] [datetime2](7) NULL,
	[UPDATEDATE] [datetime2](7) NULL,
PRIMARY KEY CLUSTERED 
(
	[IDRISKS] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [ISO].[TASKS]

-- %%
/****** Object:  Table [ISO].[TASKS]    Script Date: 4/3/2024 8:42:49 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [ISO].[TASKS](
	[IDTASK] [varchar](15) NOT NULL,
	[IDUSER] [varchar](15) NOT NULL,
	[IDRULE] [varchar](15) NOT NULL,
	[IDFLAG] [varchar](15) NOT NULL,
	[PROJECT] [varchar](100) NOT NULL,
	[EVENT_TASK] [varchar](500) NOT NULL,
	[PERSONCHANGE] [varchar](50) NULL,
	[CREATEDATE] [datetime2](7) NULL,
	[UPDATEDATE] [datetime2](7) NULL,
PRIMARY KEY CLUSTERED 
(
	[IDTASK] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [PRO].[COMPLETE_PROCCESS_TASK]

-- %%
/****** Object:  Table [PRO].[COMPLETE_PROCCESS_TASK]    Script Date: 4/3/2024 8:42:49 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [PRO].[COMPLETE_PROCCESS_TASK](
	[IDCOMPLETE] [varchar](15) NOT NULL,
	[IDPROCESS] [varchar](15) NOT NULL,
	[IDFLAG] [varchar](15) NOT NULL,
	[COMPLETED] [int] NOT NULL,
	[PERSONCHANGE] [varchar](50) NULL,
	[CREATEDATE] [datetime2](7) NULL,
	[UPDATEDATE] [datetime2](7) NULL,
PRIMARY KEY CLUSTERED 
(
	[IDCOMPLETE] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [PRO].[NO_ACCORDANCE]

-- %%
/****** Object:  Table [PRO].[NO_ACCORDANCE]    Script Date: 4/3/2024 8:42:49 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [PRO].[NO_ACCORDANCE](
	[IDACCORDANCE] [varchar](15) NOT NULL,
	[IDPROCESS] [varchar](15) NULL,
	[IDAUDIT] [varchar](15) NULL,
	[IDTASK] [varchar](15) NULL,
	[NAME_NO_ACCORDANCE] [varchar](50) NOT NULL,
	[KIND] [varchar](30) NOT NULL,
	[RANKING] [varchar](15) NOT NULL,
	[DESCRIPTION] [varchar](500) NOT NULL,
	[STATE] [bit] NULL,
	[AUDIT_DETECT] [varchar](50) NOT NULL,
	[CREATEDATE] [datetime2](7) NULL,
	[UPDATEDATE] [datetime2](7) NULL,
PRIMARY KEY CLUSTERED 
(
	[IDACCORDANCE] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [PRO].[PROCESS]

-- %%
/****** Object:  Table [PRO].[PROCESS]    Script Date: 4/3/2024 8:42:49 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [PRO].[PROCESS](
	[IDPROCESS] [varchar](15) NOT NULL,
	[IDRULE] [varchar](15) NOT NULL,
	[PROCESSNAME] [varchar](50) NOT NULL,
	[CHARGE_PERSON] [varchar](50) NOT NULL,
	[ROLE_INVOLVES] [varchar](50) NOT NULL,
	[CREATEDATE] [datetime2](7) NULL,
	[UPDATEDATE] [datetime2](7) NULL,
PRIMARY KEY CLUSTERED 
(
	[IDPROCESS] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [US].[POSITION]

-- %%
/****** Object:  Table [US].[POSITION]    Script Date: 4/3/2024 8:42:49 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [US].[POSITION](
	[IDPOSITION] [varchar](15) NOT NULL,
	[POSITIONJOB] [varchar](15) NOT NULL,
	[DESCRIPTION] [varchar](500) NOT NULL,
	[AREA] [varchar](50) NOT NULL,
	[CREATEDATE] [datetime2](7) NULL,
	[UPDATEDATE] [datetime2](7) NULL,
PRIMARY KEY CLUSTERED 
(
	[IDPOSITION] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [US].[ROLES]

-- %%
/****** Object:  Table [US].[ROLES]    Script Date: 4/3/2024 8:42:49 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [US].[ROLES](
	[IDROLE] [varchar](15) NOT NULL,
	[ROLE] [varchar](50) NOT NULL,
	[CREATEDATE] [datetime2](7) NULL,
	[UPDATEDATE] [datetime2](7) NULL,
PRIMARY KEY CLUSTERED 
(
	[IDROLE] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [US].[USERS]

-- %%
/****** Object:  Table [US].[USERS]    Script Date: 4/3/2024 8:42:49 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [US].[USERS](
	[IDUSER] [varchar](15) NOT NULL,
	[IDROLE] [varchar](15) NOT NULL,
	[IDPOSITION] [varchar](15) NOT NULL,
	[FULLNAME] [varchar](50) NOT NULL,
	[CEDULA] [varchar](13) NOT NULL,
	[EMAIL] [varchar](1500) NOT NULL,
	[PASSWORDHASH] [varbinary](max) NOT NULL,
	[PASSWORDSALT] [varbinary](max) NOT NULL,
	[ACTIVE] [bit] NULL,
	[CREATEDATE] [datetime2](7) NULL,
	[UPDATEDATE] [datetime2](7) NULL,
PRIMARY KEY CLUSTERED 
(
	[IDUSER] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [FK__FLAGS__IDRULE__38845C1C]

-- %%
ALTER TABLE [ISO].[FLAGS]  WITH CHECK ADD FOREIGN KEY([IDRULE])
REFERENCES [ISO].[ISORULE] ([IDRULE])
GO

-- %% [markdown]
-- # [FK__ISORULE__IDAUDIT__30E33A54]

-- %%
ALTER TABLE [ISO].[ISORULE]  WITH CHECK ADD FOREIGN KEY([IDAUDIT])
REFERENCES [ISO].[AUDITS] ([IDAUDIT])
GO

-- %% [markdown]
-- # [FK__ISORULE__IDCERTI__2FEF161B]

-- %%
ALTER TABLE [ISO].[ISORULE]  WITH CHECK ADD FOREIGN KEY([IDCERTIFICATION])
REFERENCES [ISO].[CERTIFICATION] ([IDCERTIFICATION])
GO

-- %% [markdown]
-- # [FK__RISKS__IDRULE__2630A1B7]

-- %%
ALTER TABLE [ISO].[RISKS]  WITH CHECK ADD FOREIGN KEY([IDRULE])
REFERENCES [ISO].[ISORULE] ([IDRULE])
GO

-- %% [markdown]
-- # [FK__TASKS__IDFLAG__3D491139]

-- %%
ALTER TABLE [ISO].[TASKS]  WITH CHECK ADD FOREIGN KEY([IDFLAG])
REFERENCES [ISO].[FLAGS] ([IDFLAG])
GO

-- %% [markdown]
-- # [FK__TASKS__IDRULE__3C54ED00]

-- %%
ALTER TABLE [ISO].[TASKS]  WITH CHECK ADD FOREIGN KEY([IDRULE])
REFERENCES [ISO].[ISORULE] ([IDRULE])
GO

-- %% [markdown]
-- # [FK__TASKS__IDUSER__3B60C8C7]

-- %%
ALTER TABLE [ISO].[TASKS]  WITH CHECK ADD FOREIGN KEY([IDUSER])
REFERENCES [US].[USERS] ([IDUSER])
GO

-- %% [markdown]
-- # [FK__COMPLETE___IDFLA__4C8B54C9]

-- %%
ALTER TABLE [PRO].[COMPLETE_PROCCESS_TASK]  WITH CHECK ADD FOREIGN KEY([IDFLAG])
REFERENCES [ISO].[FLAGS] ([IDFLAG])
GO

-- %% [markdown]
-- # [FK__COMPLETE___IDPRO__4B973090]

-- %%
ALTER TABLE [PRO].[COMPLETE_PROCCESS_TASK]  WITH CHECK ADD FOREIGN KEY([IDPROCESS])
REFERENCES [PRO].[PROCESS] ([IDPROCESS])
GO

-- %% [markdown]
-- # [FK__NO_ACCORD__IDAUD__505BE5AD]

-- %%
ALTER TABLE [PRO].[NO_ACCORDANCE]  WITH CHECK ADD FOREIGN KEY([IDAUDIT])
REFERENCES [ISO].[AUDITS] ([IDAUDIT])
GO

-- %% [markdown]
-- # [FK__NO_ACCORD__IDPRO__4F67C174]

-- %%
ALTER TABLE [PRO].[NO_ACCORDANCE]  WITH CHECK ADD FOREIGN KEY([IDPROCESS])
REFERENCES [PRO].[PROCESS] ([IDPROCESS])
GO

-- %% [markdown]
-- # [FK__NO_ACCORD__IDTAS__515009E6]

-- %%
ALTER TABLE [PRO].[NO_ACCORDANCE]  WITH CHECK ADD FOREIGN KEY([IDTASK])
REFERENCES [ISO].[TASKS] ([IDTASK])
GO

-- %% [markdown]
-- # [FK__PROCESS__IDRULE__48BAC3E5]

-- %%
ALTER TABLE [PRO].[PROCESS]  WITH CHECK ADD FOREIGN KEY([IDRULE])
REFERENCES [ISO].[ISORULE] ([IDRULE])
GO

-- %% [markdown]
-- # [FK__USERS__IDPOSITIO__1DD065E0]

-- %%
ALTER TABLE [US].[USERS]  WITH CHECK ADD FOREIGN KEY([IDPOSITION])
REFERENCES [US].[POSITION] ([IDPOSITION])
GO

-- %% [markdown]
-- # [FK__USERS__IDROLE__1CDC41A7]

-- %%
ALTER TABLE [US].[USERS]  WITH CHECK ADD FOREIGN KEY([IDROLE])
REFERENCES [US].[ROLES] ([IDROLE])
GO

-- %% [markdown]
-- # [AUD].[SP_ADD_FILES]

-- %%
/****** Object:  StoredProcedure [AUD].[SP_ADD_FILES]    Script Date: 4/3/2024 8:42:49 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
-- =============================================
-- Author:		<Author,,Name>
-- Create date: <Create Date,,>
-- Description:	<Description,,>
-- =============================================
CREATE PROCEDURE [AUD].[SP_ADD_FILES] 
	-- Add the parameters for the stored procedure here
	@IDMODULE VARCHAR(15) NULL, 
	@FILENAME VARCHAR(50) NULL, 
	@EXTENSION VARCHAR(8) NULL, 
	@BINARY_FILE VARBINARY(MAX) NULL
AS
BEGIN
	--DECLARE @COUNTER_ID INT,
	DECLARE @IDFILE VARCHAR(6) 
	--	@LASTCODE VARCHAR(15),
	--	@COUNTER INT,
	--	@SPLIT_COUNTER INT = 0


	--SET @COUNTER_ID = (SELECT COUNT(*) FROM AUD.FILES)

	--IF(@COUNTER_ID<10)
	--BEGIN
	----OBTENEMOS EL CODIGO MINIMO DE LA TABLA
 --          SET @LASTCODE = (SELECT RIGHT(MAX(IDFILE),1) FROM AUD.FILES) 
	--	   SET @SPLIT_COUNTER = 1
	--	 END
 --           ELSE IF (@COUNTER <100) 
	--		BEGIN
 --               SET @LASTCODE = (SELECT RIGHT(MAX(IDFILE),2) FROM AUD.FILES) 
	--			SET @SPLIT_COUNTER = 2
	--		END
 --               ELSE IF(@COUNTER <1000)
	--			BEGIN
 --                   SET @LASTCODE = (SELECT RIGHT(MAX(IDFILE),3) FROM AUD.FILES) 
	--				SET @SPLIT_COUNTER = 3
                --END

--SET @COUNTER = (SELECT COUNT(*)+1 FROM AUD.FILES)
	
--	SET @IDFILE = AUD.[GET_CODE_FILES](@COUNTER)

	--COMPARAMOS EL ULTIMO DIGITO DE LA TABLA 
	--IF @LASTCODE = RIGHT(@IDFILE,@SPLIT_COUNTER)
	--BEGIN 
	--SET @LASTCODE = @LASTCODE + 1
	--SET @COUNTER = @LASTCODE
	--SET @IDFILE = ISO.[GET_CODE_AUDIT](@COUNTER)
	--END
	-- SET NOCOUNT ON added to prevent extra result sets from
	-- interfering with SELECT statements.
	SET NOCOUNT ON;

    INSERT INTO AUD.FILES( IDMODULE,FILENAME,EXTENSION,BINARY_FILE, CREATEDATE, UPDATEDATE)
	VALUES (@IDMODULE,@FILENAME,@EXTENSION, @BINARY_FILE, GETDATE(), NULL)

	SELECT * FROM AUD.FILES
END
GO

-- %% [markdown]
-- # [AUD].[SP_DELETE_FILE]

-- %%
/****** Object:  StoredProcedure [AUD].[SP_DELETE_FILE]    Script Date: 4/3/2024 8:42:49 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
-- =============================================
-- Author:		<Author,,Name>
-- Create date: <Create Date,,>
-- Description:	<Description,,>
-- =============================================
CREATE PROCEDURE [AUD].[SP_DELETE_FILE]
	-- Add the parameters for the stored procedure here
	@IDMODULE VARCHAR(15) NULL, 
	@IDFILE VARCHAR(15) NULL
AS
BEGIN
	SELECT * FROM AUD.FILES WHERE IDMODULE =  @IDMODULE AND IDFILE = @IDFILE
	--UPDATE ISO.RISKS  SET IDFILE = NULL WHERE IDRISKS = @IDMODULE

	DELETE FROM AUD.FILES WHERE IDMODULE =  @IDMODULE AND IDFILE = @IDFILE

	
END
GO

-- %% [markdown]
-- # [AUD].[SP_GET_FILES_BY_ID]

-- %%
/****** Object:  StoredProcedure [AUD].[SP_GET_FILES_BY_ID]    Script Date: 4/3/2024 8:42:49 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
-- =============================================
-- Author:		<Author,,Name>
-- Create date: <Create Date,,>
-- Description:	<Description,,>
-- =============================================
CREATE PROCEDURE [AUD].[SP_GET_FILES_BY_ID]
	-- Add the parameters for the stored procedure here
	@IDMODULE VARCHAR(15) NULL
AS
BEGIN
	SELECT * FROM AUD.FILES WHERE IDMODULE =  @IDMODULE
END
GO

-- %% [markdown]
-- # [HIS].[SP_ADD_HISTORY]

-- %%
/****** Object:  StoredProcedure [HIS].[SP_ADD_HISTORY]    Script Date: 4/3/2024 8:42:49 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
-- =============================================
-- Author:		<Author,,Name>
-- Create date: <Create Date,,>
-- Description:	<Description,,>
-- =============================================
CREATE PROCEDURE [HIS].[SP_ADD_HISTORY] 
	-- Add the parameters for the stored procedure here
	@IDMODULE VARCHAR(15) NULL, 
	@PERSONCHANGE VARCHAR(50) NULL
AS
BEGIN
	DECLARE 
		@SET_HOUR TIME(6)

	SET @SET_HOUR = (SELECT format (getdate (), 'hh:mm:ss'))
	
	SET NOCOUNT ON;
	 

    INSERT INTO HIS.HISTORIAL( IDMODULE,PERSONCHANGE,DATEHISTORY,HOUR)
	VALUES (@IDMODULE,@PERSONCHANGE,GETDATE(), @SET_HOUR)

	SELECT * FROM HIS.HISTORIAL WHERE IDMODULE =  @IDMODULE 
END
GO

-- %% [markdown]
-- # [HIS].[SP_GET_HISTORIAL_BY_ID]

-- %%
/****** Object:  StoredProcedure [HIS].[SP_GET_HISTORIAL_BY_ID]    Script Date: 4/3/2024 8:42:49 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
-- =============================================
-- Author:		<Author,,Name>
-- Create date: <Create Date,,>
-- Description:	<Description,,>
-- =============================================
CREATE PROCEDURE [HIS].[SP_GET_HISTORIAL_BY_ID]
	-- Add the parameters for the stored procedure here
	@IDMODULE VARCHAR(15) NULL
AS
BEGIN
	SELECT * FROM HIS.HISTORIAL WHERE IDMODULE =  @IDMODULE
END
GO

-- %% [markdown]
-- # [ISO].[SP_ADD_AUDIT]

-- %%
/****** Object:  StoredProcedure [ISO].[SP_ADD_AUDIT]    Script Date: 4/3/2024 8:42:49 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
-- =============================================
-- Author:		<Author,,Name>
-- Create date: <Create Date,,>
-- Description:	<Description,,>
-- =============================================
CREATE PROCEDURE [ISO].[SP_ADD_AUDIT] 
	-- Add the parameters for the stored procedure here
	@AUDIT_NAME VARCHAR(150) NULL, 
	@AUDIT_DATE DATETIME2(7) NULL, 
	@AUDIT_TIME TIME(6) NULL, 
	@AUDIT_SUBJECT VARCHAR(100) NULL, 
	@NUMBER_DAYS INT NULL,
	@KIND_AUDIT VARCHAR(100) NULL, 
	@SCOPE_AUDIT VARCHAR(100) NULL, 
	@AUDIT_PROCESS VARCHAR(100) NULL, 
	@AUDIT_RULE VARCHAR(50) NULL
AS
BEGIN
	DECLARE @COUNTER_ID INT,
	@IDAUDIT VARCHAR(15),
		@LASTCODE VARCHAR(15),
		@COUNTER INT,
		@SPLIT_COUNTER INT = 0


	--SET @COUNTER_ID = (SELECT COUNT(*) FROM ISO.AUDITS)

	--IF(@COUNTER_ID<10)
	--BEGIN
	----OBTENEMOS EL CODIGO MINIMO DE LA TABLA
 --          SET @LASTCODE = (SELECT RIGHT(MAX(IDAUDIT),1) FROM ISO.AUDITS) 
	--	   SET @SPLIT_COUNTER = 1
	--	 END
 --           ELSE IF (@COUNTER <100) 
	--		BEGIN
 --               SET @LASTCODE = (SELECT RIGHT(MAX(IDAUDIT),2) FROM ISO.AUDITS) 
	--			SET @SPLIT_COUNTER = 2
	--		END
 --               ELSE IF(@COUNTER <1000)
	--			BEGIN
 --                   SET @LASTCODE = (SELECT RIGHT(MAX(IDAUDIT),3) FROM ISO.AUDITS) 
	--				SET @SPLIT_COUNTER = 3
 --               END

SET @COUNTER = (SELECT COUNT(*)+1 FROM ISO.AUDITS)
	
	SET @IDAUDIT = ISO.[GET_CODE_AUDIT](@COUNTER)

	----COMPARAMOS EL ULTIMO DIGITO DE LA TABLA 
	--IF @LASTCODE = RIGHT(@IDAUDIT,@SPLIT_COUNTER)
	--BEGIN 
	--SET @LASTCODE = @LASTCODE + 1
	--SET @COUNTER = @LASTCODE
	--SET @IDAUDIT = ISO.[GET_CODE_AUDIT](@COUNTER)
	--END
	-- SET NOCOUNT ON added to prevent extra result sets from
	-- interfering with SELECT statements.
	SET NOCOUNT ON;

    INSERT INTO ISO.AUDITS(IDAUDIT,AUDIT_NAME, AUDIT_DATE, AUDIT_TIME, AUDIT_SUBJECT, NUMBER_DAYS, KIND_AUDIT, SCOPE_AUDIT, AUDIT_PROCESS, AUDIT_RULE, CREATEDATE, UPDATEDATE)
	VALUES (@IDAUDIT,@AUDIT_NAME, @AUDIT_DATE, @AUDIT_TIME, @AUDIT_SUBJECT, @NUMBER_DAYS,@KIND_AUDIT, @SCOPE_AUDIT,@AUDIT_PROCESS, @AUDIT_TIME, GETDATE(), NULL)

	SELECT * FROM ISO.AUDITS
END
GO

-- %% [markdown]
-- # [ISO].[SP_ADD_CERTIFICATION]

-- %%
/****** Object:  StoredProcedure [ISO].[SP_ADD_CERTIFICATION]    Script Date: 4/3/2024 8:42:49 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
-- =============================================
-- Author:		<Author,,Name>
-- Create date: <Create Date,,>
-- Description:	<Description,,>
-- =============================================
CREATE PROCEDURE [ISO].[SP_ADD_CERTIFICATION]
	-- Add the parameters for the stored procedure here
	@CERTIFICATION_NAME VARCHAR(100) NULL, 
	@CERTIFICATION_DATE DATETIME2(7) NULL
AS
BEGIN
	DECLARE @COUNTER_ID INT,
	@IDCERTIFICATION VARCHAR(15),
		@LASTCODE VARCHAR(15),
		@COUNTER INT,
		@SPLIT_COUNTER INT = 0


	SET @COUNTER_ID = (SELECT COUNT(*) FROM ISO.CERTIFICATION)

	IF(@COUNTER_ID<10)
	BEGIN
	--OBTENEMOS EL CODIGO MINIMO DE LA TABLA
           SET @LASTCODE = (SELECT RIGHT(MAX(IDCERTIFICATION),1) FROM ISO.CERTIFICATION) 
		   SET @SPLIT_COUNTER = 1
		 END
            ELSE IF (@COUNTER <100) 
			BEGIN
                SET @LASTCODE = (SELECT RIGHT(MAX(IDCERTIFICATION),2) FROM ISO.CERTIFICATION) 
				SET @SPLIT_COUNTER = 2
			END
                ELSE IF(@COUNTER <1000)
				BEGIN
                    SET @LASTCODE = (SELECT RIGHT(MAX(IDCERTIFICATION),3) FROM ISO.CERTIFICATION) 
					SET @SPLIT_COUNTER = 3
                END

SET @COUNTER = (SELECT COUNT(*)+1 FROM ISO.CERTIFICATION)
	
	SET @IDCERTIFICATION = ISO.[GET_CODE_CERTIFICATION](@COUNTER)

	--COMPARAMOS EL ULTIMO DIGITO DE LA TABLA 
	IF @LASTCODE = RIGHT(@IDCERTIFICATION,@SPLIT_COUNTER)
	BEGIN 
	SET @LASTCODE = @LASTCODE + 1
	SET @COUNTER = @LASTCODE
	SET @IDCERTIFICATION = ISO.[GET_CODE_CERTIFICATION](@COUNTER)
	END

	INSERT INTO ISO.CERTIFICATION (IDCERTIFICATION, CERTIFICATION_NAME, CERTIFICACION_DATE, CREATEDATE, UPDATEDATE)
	VALUES(@IDCERTIFICATION, @CERTIFICATION_NAME, @CERTIFICATION_DATE, GETDATE(), NULL)

	SELECT * FROM ISO.CERTIFICATION WHERE IDCERTIFICATION = @IDCERTIFICATION
END
GO

-- %% [markdown]
-- # [ISO].[SP_ADD_FLAG]

-- %%
/****** Object:  StoredProcedure [ISO].[SP_ADD_FLAG]    Script Date: 4/3/2024 8:42:49 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
-- =============================================
-- Author:		<Author,,Name>
-- Create date: <Create Date,,>
-- Description:	<Description,,>
-- =============================================
CREATE PROCEDURE [ISO].[SP_ADD_FLAG]
	-- Add the parameters for the stored procedure here
	@IDRULE VARCHAR(15) NULL,
	@FLAGNAME VARCHAR(150) NULL
AS
BEGIN
DECLARE @COUNTER_ID INT,
	@IDFLAG VARCHAR(15),
		@LASTCODE VARCHAR(15),
		@COUNTER INT,
		@SPLIT_COUNTER INT = 0


	SET @COUNTER_ID = (SELECT COUNT(*) FROM ISO.FLAGS)

	IF(@COUNTER_ID<10)
	BEGIN
	--OBTENEMOS EL CODIGO MINIMO DE LA TABLA
           SET @LASTCODE = (SELECT RIGHT(MAX(IDFLAG),1) FROM ISO.FLAGS) 
		   SET @SPLIT_COUNTER = 1
		 END
            ELSE IF (@COUNTER <100) 
			BEGIN
                SET @LASTCODE = (SELECT RIGHT(MAX(IDFLAG),2) FROM ISO.FLAGS) 
				SET @SPLIT_COUNTER = 2
			END
                ELSE IF(@COUNTER <1000)
				BEGIN
                    SET @LASTCODE = (SELECT RIGHT(MAX(IDFLAG),3) FROM ISO.FLAGS) 
					SET @SPLIT_COUNTER = 3
                END

SET @COUNTER = (SELECT COUNT(*)+1 FROM ISO.FLAGS)
	
	SET @IDFLAG = ISO.[GET_CODE_FLAG](@COUNTER)

	--COMPARAMOS EL ULTIMO DIGITO DE LA TABLA 
	IF @LASTCODE = RIGHT(@IDFLAG,@SPLIT_COUNTER)
	BEGIN 
	SET @LASTCODE = @LASTCODE + 1
	SET @COUNTER = @LASTCODE
	SET @IDFLAG = ISO.[GET_CODE_FLAG](@COUNTER)
	END
	-- SET NOCOUNT ON added to prevent extra result sets from
	-- interfering with SELECT statements.
	SET NOCOUNT ON;

    INSERT INTO ISO.FLAGS(IDFLAG, IDRULE,FLAGNAME,CREATEDATE, UPDATEDATE)
	VALUES (@IDFLAG,@IDRULE, @FLAGNAME, GETDATE(), NULL)

	SELECT * FROM ISO.FLAGS F, ISO.ISORULE I WHERE F.IDRULE = I.IDRULE  
END
GO

-- %% [markdown]
-- # [ISO].[SP_ADD_ISORULE]

-- %%
/****** Object:  StoredProcedure [ISO].[SP_ADD_ISORULE]    Script Date: 4/3/2024 8:42:49 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
-- =============================================
-- Author:		<Author,,Name>
-- Create date: <Create Date,,>
-- Description:	<Description,,>
-- =============================================
CREATE PROCEDURE [ISO].[SP_ADD_ISORULE]
	-- Add the parameters for the stored procedure here
	@IDCERTIFICATION VARCHAR(15) NULL,
	@IDAUDIT VARCHAR(15) NULL, 
	@NAMERULE VARCHAR(50) NULL, 
	@RULE_DESCRIPTION VARCHAR(MAX) NULL
AS
BEGIN
DECLARE @COUNTER_ID INT,
		@IDRULE VARCHAR(15),
		@LASTCODE VARCHAR(15),
		@COUNTER INT,
		@SPLIT_COUNTER INT = 0


	SET @COUNTER_ID = (SELECT COUNT(*) FROM ISO.ISORULE)

	IF(@COUNTER_ID<10)
	BEGIN
	--OBTENEMOS EL CODIGO MINIMO DE LA TABLA
           SET @LASTCODE = (SELECT RIGHT(MAX(IDRULE),1) FROM ISO.ISORULE) 
		   SET @SPLIT_COUNTER = 1
		 END
            ELSE IF (@COUNTER <100) 
			BEGIN
                SET @LASTCODE = (SELECT RIGHT(MAX(IDRULE),2) FROM ISO.ISORULE) 
				SET @SPLIT_COUNTER = 2
			END
                ELSE IF(@COUNTER <1000)
				BEGIN
                    SET @LASTCODE = (SELECT RIGHT(MAX(IDRULE),3) FROM ISO.ISORULE) 
					SET @SPLIT_COUNTER = 3
                END

SET @COUNTER = (SELECT COUNT(*)+1 FROM ISO.ISORULE)
	
	SET @IDRULE = ISO.[GET_CODE_ISORULE](@COUNTER)

	--COMPARAMOS EL ULTIMO DIGITO DE LA TABLA 
	IF @LASTCODE = RIGHT(@IDRULE,@SPLIT_COUNTER)
	BEGIN 
	SET @LASTCODE = @LASTCODE + 1
	SET @COUNTER = @LASTCODE
	SET @IDRULE = ISO.[GET_CODE_ISORULE](@COUNTER)
	END
	-- SET NOCOUNT ON added to prevent extra result sets from
	-- interfering with SELECT statements.
	SET NOCOUNT ON;

	INSERT INTO ISO.ISORULE(IDRULE, IDCERTIFICATION, IDAUDIT,NAMERULE,RULE_DESCRIPTION,CREATEDATE, UPDATEDATE)
	VALUES (@IDRULE,@IDCERTIFICATION, @IDAUDIT, @NAMERULE, @RULE_DESCRIPTION, GETDATE(), NULL)

	SELECT * FROM ISO.ISORULE R, ISO.CERTIFICATION C, ISO.AUDITS A WHERE R.IDAUDIT = A.IDAUDIT AND R.IDCERTIFICATION = C.IDCERTIFICATION  
END
GO

-- %% [markdown]
-- # [ISO].[SP_ADD_RISK]

-- %%
/****** Object:  StoredProcedure [ISO].[SP_ADD_RISK]    Script Date: 4/3/2024 8:42:49 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
-- =============================================
-- Author:		<Author,,Name>
-- Create date: <Create Date,,>
-- Description:	<Description,,>
-- =============================================
CREATE PROCEDURE [ISO].[SP_ADD_RISK]
	-- Add the parameters for the stored procedure here
	@IDRULE VARCHAR(15) NULL,
	@NAMERISKS VARCHAR(50)NULL,
	@ORIGEN VARCHAR(50) NULL, 
	@STATE BIT NULL, 
	@CONSEQUENSE VARCHAR(500) NULL, 
	@SOURCE_RISK VARCHAR(100) NULL
AS
BEGIN
	DECLARE @COUNTER_ID INT,
	@IDRISK VARCHAR(15),
		@LASTCODE VARCHAR(15),
		@COUNTER INT,
		@SPLIT_COUNTER INT = 0


	SET @COUNTER_ID = (SELECT COUNT(*) FROM ISO.RISKS)

	IF(@COUNTER_ID<10)
	BEGIN
	--OBTENEMOS EL CODIGO MINIMO DE LA TABLA
           SET @LASTCODE = (SELECT RIGHT(MAX(IDRISKS),1) FROM ISO.RISKS) 
		   SET @SPLIT_COUNTER = 1
		 END
            ELSE IF (@COUNTER <100) 
			BEGIN
                SET @LASTCODE = (SELECT RIGHT(MAX(IDRISKS),2) FROM ISO.RISKS) 
				SET @SPLIT_COUNTER = 2
			END
                ELSE IF(@COUNTER <1000)
				BEGIN
                    SET @LASTCODE = (SELECT RIGHT(MAX(IDRISKS),3) FROM ISO.RISKS) 
					SET @SPLIT_COUNTER = 3
                END

SET @COUNTER = (SELECT COUNT(*)+1 FROM ISO.RISKS)
	
	SET @IDRISK = ISO.[GET_CODE_RISKS](@COUNTER)

	--COMPARAMOS EL ULTIMO DIGITO DE LA TABLA 
	IF @LASTCODE = RIGHT(@IDRISK,@SPLIT_COUNTER)
	BEGIN 
	SET @LASTCODE = @LASTCODE + 1
	SET @COUNTER = @LASTCODE
	SET @IDRISK = ISO.[GET_CODE_RISKS](@COUNTER)
	END
	-- SET NOCOUNT ON added to prevent extra result sets from
	-- interfering with SELECT statements.
	SET NOCOUNT ON;

    INSERT INTO ISO.RISKS(IDRISKS, IDRULE,NAMERISKS,ORIGEN,CONSEQUENSE,SOURCE_RISK,STATE, CREATEDATE, UPDATEDATE)
	VALUES (@IDRISK,@IDRULE, @NAMERISKS,@ORIGEN,@CONSEQUENSE, @SOURCE_RISK, 1, GETDATE(), NULL)

	SELECT * FROM ISO.RISKS R, ISO.ISORULE IR, AUD.FILES F WHERE R.IDRULE = IR.IDRULE AND R.IDRISKS =  @IDRISK
END
GO

-- %% [markdown]
-- # [ISO].[SP_ADD_TASK]

-- %%
/****** Object:  StoredProcedure [ISO].[SP_ADD_TASK]    Script Date: 4/3/2024 8:42:49 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
-- =============================================
-- Author:		<Author,,Name>
-- Create date: <Create Date,,>
-- Description:	<Description,,>
-- =============================================
CREATE PROCEDURE [ISO].[SP_ADD_TASK]
	-- Add the parameters for the stored procedure here
	@IDRULE VARCHAR(15) NULL,
	@IDUSER VARCHAR(15) NULL,
	@IDFLAGS VARCHAR(15) NULL,
	@PROJECT VARCHAR(100)NULL,
	@EVENT_TASK VARCHAR(500) NULL
AS
BEGIN

	DECLARE @COUNTER_ID INT,
	@IDTASK VARCHAR(15),
		@LASTCODE VARCHAR(15),
		@COUNTER INT,
		@SPLIT_COUNTER INT = 0


	--SET @COUNTER_ID = (SELECT COUNT(*) FROM ISO.TASKS)

	--IF(@COUNTER_ID<10)
	--BEGIN
	--OBTENEMOS EL CODIGO MINIMO DE LA TABLA
   --        SET @LASTCODE = (SELECT RIGHT(MAX(IDTASK),1) FROM ISO.TASKS) 
		 --  SET @SPLIT_COUNTER = 1
		 --END
   --         ELSE IF (@COUNTER <100) 
			--BEGIN
   --             SET @LASTCODE = (SELECT RIGHT(MAX(IDTASK),2) FROM ISO.TASKS) 
			--	SET @SPLIT_COUNTER = 2
			--END
   --             ELSE IF(@COUNTER <1000)
			--	BEGIN
   --                 SET @LASTCODE = (SELECT RIGHT(MAX(IDTASK),3) FROM ISO.TASKS) 
			--		SET @SPLIT_COUNTER = 3
   --             END

SET @COUNTER = (SELECT COUNT(*)+1 FROM ISO.TASKS)
	
	SET @IDTASK = ISO.[GET_CODE_TASK](@COUNTER)

	----COMPARAMOS EL ULTIMO DIGITO DE LA TABLA 
	--IF @LASTCODE = RIGHT(@IDTASK,@SPLIT_COUNTER)
	--BEGIN 
	--SET @LASTCODE = @LASTCODE + 1
	--SET @COUNTER = @LASTCODE
	--SET @IDTASK = ISO.[GET_CODE_TASK](@COUNTER)
	--END
	-- SET NOCOUNT ON added to prevent extra result sets from
	-- interfering with SELECT statements.
	SET NOCOUNT ON;

    INSERT INTO ISO.TASKS(IDTASK,IDUSER,IDRULE,IDFLAG,PROJECT,EVENT_TASK, CREATEDATE, UPDATEDATE)
	VALUES (@IDTASK,@IDUSER,@IDRULE,@IDFLAGS, @PROJECT, @EVENT_TASK, GETDATE(), NULL)

	SELECT * FROM ISO.TASKS T, ISO.ISORULE R, ISO.FLAGS F, US.USERS U WHERE T.IDFLAG= F.IDFLAG AND T.IDUSER = U.IDUSER
	AND T.IDRULE = R.IDRULE
END
GO

-- %% [markdown]
-- # [ISO].[SP_DELETE_AUDIT]

-- %%
/****** Object:  StoredProcedure [ISO].[SP_DELETE_AUDIT]    Script Date: 4/3/2024 8:42:49 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
-- =============================================
-- Author:		<Author,,Name>
-- Create date: <Create Date,,>
-- Description:	<Description,,>
-- =============================================
CREATE PROCEDURE [ISO].[SP_DELETE_AUDIT]
	-- Add the parameters for the stored procedure here
	@IDAUDIT VARCHAR(15) NULL
AS
BEGIN
	
	SELECT * FROM ISO.AUDITS WHERE IDAUDIT = @IDAUDIT

	DELETE FROM ISO.AUDITS  WHERE IDAUDIT = @IDAUDIT
END
GO

-- %% [markdown]
-- # [ISO].[SP_GET_ALL_AUDITS]

-- %%
/****** Object:  StoredProcedure [ISO].[SP_GET_ALL_AUDITS]    Script Date: 4/3/2024 8:42:49 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
-- =============================================
-- Author:		<Author,,Name>
-- Create date: <Create Date,,>
-- Description:	<Description,,>
-- =============================================
CREATE PROCEDURE [ISO].[SP_GET_ALL_AUDITS]
	
AS
BEGIN
	SELECT *, (SELECT TOP(1) H.PERSONCHANGE FROM HIS.HISTORIAL H WHERE IDMODULE = A.IDAUDIT ORDER BY DATEHISTORY DESC) as PERSONCHANGE FROM ISO.AUDITS A
END
GO

-- %% [markdown]
-- # [ISO].[SP_GET_ALL_CERTIFICATION]

-- %%
/****** Object:  StoredProcedure [ISO].[SP_GET_ALL_CERTIFICATION]    Script Date: 4/3/2024 8:42:49 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
-- =============================================
-- Author:		<Author,,Name>
-- Create date: <Create Date,,>
-- Description:	<Description,,>
-- =============================================
CREATE PROCEDURE [ISO].[SP_GET_ALL_CERTIFICATION]
	
AS
BEGIN
	SELECT *, (SELECT TOP(1) H.PERSONCHANGE FROM HIS.HISTORIAL H WHERE IDMODULE = C.IDCERTIFICATION ORDER BY DATEHISTORY DESC) as PERSONCHANGE FROM ISO.CERTIFICATION C 
END
GO

-- %% [markdown]
-- # [ISO].[SP_GET_ALL_FLAG]

-- %%
/****** Object:  StoredProcedure [ISO].[SP_GET_ALL_FLAG]    Script Date: 4/3/2024 8:42:49 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
-- =============================================
-- Author:		<Author,,Name>
-- Create date: <Create Date,,>
-- Description:	<Description,,>
-- =============================================
CREATE PROCEDURE [ISO].[SP_GET_ALL_FLAG]
	
AS
BEGIN
	SELECT F.* , (SELECT TOP(1) H.PERSONCHANGE FROM HIS.HISTORIAL H WHERE IDMODULE = F.IDFLAG ORDER BY DATEHISTORY DESC) as PERSONCHANGE,I.* 
	FROM ISO.FLAGS F, ISO.ISORULE I WHERE F.IDRULE = I.IDRULE  
END
GO

-- %% [markdown]
-- # [ISO].[SP_GET_ALL_ISORULE]

-- %%
/****** Object:  StoredProcedure [ISO].[SP_GET_ALL_ISORULE]    Script Date: 4/3/2024 8:42:49 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
-- =============================================
-- Author:		<Author,,Name>
-- Create date: <Create Date,,>
-- Description:	<Description,,>
-- =============================================
CREATE PROCEDURE [ISO].[SP_GET_ALL_ISORULE]
	
AS
BEGIN
	SELECT  R.*,(SELECT TOP(1) H.PERSONCHANGE FROM HIS.HISTORIAL H WHERE IDMODULE = R.IDRULE ORDER BY DATEHISTORY DESC) as PERSONCHANGE,C.*,A.*
	FROM ISO.ISORULE R, ISO.CERTIFICATION C, ISO.AUDITS A WHERE R.IDAUDIT = A.IDAUDIT AND R.IDCERTIFICATION = C.IDCERTIFICATION   
END
GO

-- %% [markdown]
-- # [ISO].[SP_GET_ALL_RISK]

-- %%
/****** Object:  StoredProcedure [ISO].[SP_GET_ALL_RISK]    Script Date: 4/3/2024 8:42:49 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
-- =============================================
-- Author:		<Author,,Name>
-- Create date: <Create Date,,>
-- Description:	<Description,,>
-- =============================================
CREATE PROCEDURE [ISO].[SP_GET_ALL_RISK]
	-- Add the parameters for the stored procedure here
AS
BEGIN
	SELECT R.*, (SELECT COUNT(*) FROM AUD.FILES WHERE IDMODULE = R.IDRISKS) QUANTITY,IR.* FROM ISO.RISKS R, ISO.ISORULE IR WHERE R.IDRULE = IR.IDRULE 
END
GO

-- %% [markdown]
-- # [ISO].[SP_GET_ALL_TASK]

-- %%
/****** Object:  StoredProcedure [ISO].[SP_GET_ALL_TASK]    Script Date: 4/3/2024 8:42:49 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
-- =============================================
-- Author:		<Author,,Name>
-- Create date: <Create Date,,>
-- Description:	<Description,,>
-- =============================================
CREATE PROCEDURE [ISO].[SP_GET_ALL_TASK]
	
AS
BEGIN
	SELECT T.*,U.*,R.*,F.* FROM ISO.TASKS T
	INNER JOIN US.USERS U   ON T.IDUSER = U.IDUSER
	INNER JOIN ISO.ISORULE R ON T.IDRULE = R.IDRULE 
	INNER JOIN ISO.FLAGS F ON T.IDFLAG= F.IDFLAG
END
GO

-- %% [markdown]
-- # [ISO].[SP_GET_AUDITS_BY_ID]

-- %%
/****** Object:  StoredProcedure [ISO].[SP_GET_AUDITS_BY_ID]    Script Date: 4/3/2024 8:42:49 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
-- =============================================
-- Author:		<Author,,Name>
-- Create date: <Create Date,,>
-- Description:	<Description,,>
-- =============================================
CREATE PROCEDURE [ISO].[SP_GET_AUDITS_BY_ID]
	-- Add the parameters for the stored procedure here
	@IDAUDIT VARCHAR(15) NULL
AS
BEGIN
	SELECT *, (SELECT TOP(1) H.PERSONCHANGE FROM HIS.HISTORIAL H WHERE IDMODULE = A.IDAUDIT ORDER BY DATEHISTORY DESC) as PERSONCHANGE FROM ISO.AUDITS A WHERE IDAUDIT =  @IDAUDIT
END
GO

-- %% [markdown]
-- # [ISO].[SP_GET_CERTIFICATION_BY_ID]

-- %%
/****** Object:  StoredProcedure [ISO].[SP_GET_CERTIFICATION_BY_ID]    Script Date: 4/3/2024 8:42:49 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
-- =============================================
-- Author:		<Author,,Name>
-- Create date: <Create Date,,>
-- Description:	<Description,,>
-- =============================================
CREATE PROCEDURE [ISO].[SP_GET_CERTIFICATION_BY_ID]
	-- Add the parameters for the stored procedure here
	@IDCERTIFICATION VARCHAR(15) NULL
AS
BEGIN
	SELECT *, (SELECT TOP(1) H.PERSONCHANGE FROM HIS.HISTORIAL H WHERE IDMODULE = C.IDCERTIFICATION ORDER BY DATEHISTORY DESC) as PERSONCHANGE 
	FROM ISO.CERTIFICATION C WHERE IDCERTIFICATION =  @IDCERTIFICATION
END
GO

-- %% [markdown]
-- # [ISO].[SP_GET_FLAG_BY_ID]

-- %%
/****** Object:  StoredProcedure [ISO].[SP_GET_FLAG_BY_ID]    Script Date: 4/3/2024 8:42:49 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
-- =============================================
-- Author:		<Author,,Name>
-- Create date: <Create Date,,>
-- Description:	<Description,,>
-- =============================================
CREATE PROCEDURE [ISO].[SP_GET_FLAG_BY_ID]
	-- Add the parameters for the stored procedure here
	@IDFLAGS VARCHAR(15) NULL
AS
BEGIN
	SELECT *, (SELECT TOP(1) H.PERSONCHANGE FROM HIS.HISTORIAL H WHERE IDMODULE = F.IDFLAG ORDER BY DATEHISTORY DESC) as PERSONCHANGE 
	FROM ISO.FLAGS F, ISO.ISORULE I WHERE F.IDRULE = I.IDRULE  AND F.IDFLAG =  @IDFLAGS
END
GO

-- %% [markdown]
-- # [ISO].[SP_GET_ISORULE_BY_ID]

-- %%
/****** Object:  StoredProcedure [ISO].[SP_GET_ISORULE_BY_ID]    Script Date: 4/3/2024 8:42:49 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
-- =============================================
-- Author:		<Author,,Name>
-- Create date: <Create Date,,>
-- Description:	<Description,,>
-- =============================================
CREATE PROCEDURE [ISO].[SP_GET_ISORULE_BY_ID]
	-- Add the parameters for the stored procedure here
	@IDRULE VARCHAR(15) NULL
AS
BEGIN
SELECT  R.*,(SELECT TOP(1) H.PERSONCHANGE FROM HIS.HISTORIAL H WHERE IDMODULE = R.IDRULE ORDER BY DATEHISTORY DESC) as PERSONCHANGE,C.*,A.*
	FROM ISO.ISORULE R, ISO.CERTIFICATION C, ISO.AUDITS A WHERE R.IDAUDIT = A.IDAUDIT AND R.IDCERTIFICATION = C.IDCERTIFICATION  AND IDRULE = @IDRULE 
END
GO

-- %% [markdown]
-- # [ISO].[SP_GET_RISK_BY_ID]

-- %%
/****** Object:  StoredProcedure [ISO].[SP_GET_RISK_BY_ID]    Script Date: 4/3/2024 8:42:49 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
-- =============================================
-- Author:		<Author,,Name>
-- Create date: <Create Date,,>
-- Description:	<Description,,>
-- =============================================
CREATE PROCEDURE [ISO].[SP_GET_RISK_BY_ID]
	-- Add the parameters for the stored procedure here
	@IDRISKS VARCHAR(15) NULL
AS
BEGIN
	SELECT * FROM ISO.RISKS R, ISO.ISORULE IR WHERE R.IDRULE = IR.IDRULE AND R.IDRISKS =  @IDRISKS
END
GO

-- %% [markdown]
-- # [ISO].[SP_GET_TASK_BY_ID]

-- %%
/****** Object:  StoredProcedure [ISO].[SP_GET_TASK_BY_ID]    Script Date: 4/3/2024 8:42:49 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
-- =============================================
-- Author:		<Author,,Name>
-- Create date: <Create Date,,>
-- Description:	<Description,,>
-- =============================================
CREATE PROCEDURE [ISO].[SP_GET_TASK_BY_ID]
	-- Add the parameters for the stored procedure here
	@IDTASK VARCHAR(15) NULL
AS
BEGIN
	SELECT * FROM ISO.TASKS T, ISO.ISORULE R, ISO.FLAGS F, US.USERS U WHERE T.IDFLAG= F.IDFLAG AND T.IDUSER = U.IDUSER
	AND T.IDRULE = R.IDRULE AND T.IDTASK = @IDTASK
END
GO

-- %% [markdown]
-- # [ISO].[SP_REMOVE_CERTIFICATION]

-- %%
/****** Object:  StoredProcedure [ISO].[SP_REMOVE_CERTIFICATION]    Script Date: 4/3/2024 8:42:49 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
-- =============================================
-- Author:		<Author,,Name>
-- Create date: <Create Date,,>
-- Description:	<Description,,>
-- =============================================
CREATE PROCEDURE [ISO].[SP_REMOVE_CERTIFICATION]
	-- Add the parameters for the stored procedure here
	@IDCERTIFICATION VARCHAR(15) NULL
AS
BEGIN

	SELECT * FROM ISO.CERTIFICATION WHERE IDCERTIFICATION = @IDCERTIFICATION

	DELETE FROM ISO.CERTIFICATION
	WHERE IDCERTIFICATION = @IDCERTIFICATION

	
END
GO

-- %% [markdown]
-- # [ISO].[SP_REMOVE_FLAG]

-- %%
/****** Object:  StoredProcedure [ISO].[SP_REMOVE_FLAG]    Script Date: 4/3/2024 8:42:49 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
-- =============================================
-- Author:		<Author,,Name>
-- Create date: <Create Date,,>
-- Description:	<Description,,>
-- =============================================
CREATE PROCEDURE [ISO].[SP_REMOVE_FLAG]
	-- Add the parameters for the stored procedure here
	@IDFLAGS VARCHAR(15) NULL
AS
BEGIN
	
	SELECT * FROM ISO.FLAGS F, ISO.ISORULE I WHERE F.IDRULE = I.IDRULE  AND IDFLAG = @IDFLAGS

	DELETE FROM ISO.FLAGS WHERE IDFLAG = @IDFLAGS
END
GO

-- %% [markdown]
-- # [ISO].[SP_REMOVE_ISORULE]

-- %%
/****** Object:  StoredProcedure [ISO].[SP_REMOVE_ISORULE]    Script Date: 4/3/2024 8:42:49 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
-- =============================================
-- Author:		<Author,,Name>
-- Create date: <Create Date,,>
-- Description:	<Description,,>
-- =============================================
CREATE PROCEDURE [ISO].[SP_REMOVE_ISORULE]
	-- Add the parameters for the stored procedure here
	@IDRULE VARCHAR(15) NULL
AS
BEGIN
	
	SELECT * FROM ISO.ISORULE R, ISO.CERTIFICATION C, ISO.AUDITS A WHERE R.IDAUDIT = A.IDAUDIT AND R.IDCERTIFICATION = C.IDCERTIFICATION  AND IDRULE = @IDRULE 

	DELETE FROM ISO.ISORULE WHERE IDRULE = @IDRULE
END
GO

-- %% [markdown]
-- # [ISO].[SP_REMOVE_RISK]

-- %%
/****** Object:  StoredProcedure [ISO].[SP_REMOVE_RISK]    Script Date: 4/3/2024 8:42:49 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
-- =============================================
-- Author:		<Author,,Name>
-- Create date: <Create Date,,>
-- Description:	<Description,,>
-- =============================================
CREATE PROCEDURE [ISO].[SP_REMOVE_RISK]
	-- Add the parameters for the stored procedure here
	@IDRISKS VARCHAR(15) NULL
AS
BEGIN
	
	SELECT * FROM ISO.RISKS R, ISO.ISORULE IR WHERE R.IDRULE = IR.IDRULE AND R.IDRISKS =  @IDRISKS 

	DELETE FROM ISO.RISKS WHERE IDRISKS = @IDRISKS
END
GO

-- %% [markdown]
-- # [ISO].[SP_REMOVE_TASK]

-- %%
/****** Object:  StoredProcedure [ISO].[SP_REMOVE_TASK]    Script Date: 4/3/2024 8:42:49 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
-- =============================================
-- Author:		<Author,,Name>
-- Create date: <Create Date,,>
-- Description:	<Description,,>
-- =============================================
CREATE PROCEDURE [ISO].[SP_REMOVE_TASK]
	-- Add the parameters for the stored procedure here
	@IDTASK VARCHAR(15) NULL
AS
BEGIN
	
	SELECT * FROM ISO.TASKS T, ISO.ISORULE R, ISO.FLAGS F, US.USERS U WHERE T.IDFLAG= F.IDFLAG AND T.IDUSER = U.IDUSER
	AND T.IDRULE = R.IDRULE AND T.IDTASK = @IDTASK  

	DELETE FROM ISO.TASKS WHERE IDTASK = @IDTASK
END
GO

-- %% [markdown]
-- # [ISO].[SP_UPDATE_AUDIT]

-- %%
/****** Object:  StoredProcedure [ISO].[SP_UPDATE_AUDIT]    Script Date: 4/3/2024 8:42:49 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
-- =============================================
-- Author:		<Author,,Name>
-- Create date: <Create Date,,>
-- Description:	<Description,,>
-- =============================================
CREATE PROCEDURE [ISO].[SP_UPDATE_AUDIT] 
	-- Add the parameters for the stored procedure here
	@IDAUDITS VARCHAR(150) NULL,
	@AUDIT_NAME VARCHAR(15) NULL, 
	@AUDIT_DATE DATETIME2(7) NULL, 
	@AUDIT_TIME TIME(6) NULL, 
	@AUDIT_SUBJECT VARCHAR(100) NULL, 
	@NUMBER_DAYS INT NULL,
	@KIND_AUDIT VARCHAR(100) NULL, 
	@SCOPE_AUDIT VARCHAR(100) NULL, 
	@AUDIT_PROCESS VARCHAR(100) NULL, 
	@AUDIT_RULE VARCHAR(50) NULL
AS
BEGIN
	UPDATE ISO.AUDITS SET 
	AUDIT_NAME =  @AUDIT_NAME, AUDIT_DATE = @AUDIT_DATE, 
	AUDIT_TIME =  @AUDIT_TIME, AUDIT_SUBJECT = @AUDIT_SUBJECT, NUMBER_DAYS =  @NUMBER_DAYS,
	KIND_AUDIT = @KIND_AUDIT, SCOPE_AUDIT = @SCOPE_AUDIT, AUDIT_PROCESS =  @AUDIT_PROCESS, 
	AUDIT_RULE = @AUDIT_RULE, UPDATEDATE =  GETDATE()
	WHERE IDAUDIT = @IDAUDITS

	SELECT *, (SELECT TOP(1) H.PERSONCHANGE FROM HIS.HISTORIAL H WHERE IDMODULE = A.IDAUDIT ORDER BY DATEHISTORY DESC) as PERSONCHANGE FROM ISO.AUDITS A
END
GO

-- %% [markdown]
-- # [ISO].[SP_UPDATE_CERTIFICATION]

-- %%
/****** Object:  StoredProcedure [ISO].[SP_UPDATE_CERTIFICATION]    Script Date: 4/3/2024 8:42:49 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
-- =============================================
-- Author:		<Author,,Name>
-- Create date: <Create Date,,>
-- Description:	<Description,,>
-- =============================================
CREATE PROCEDURE [ISO].[SP_UPDATE_CERTIFICATION]
	-- Add the parameters for the stored procedure here
	@IDCERTIFICATION VARCHAR(15) NULL,
	@CERTIFICATION_NAME VARCHAR(100) NULL,
	@CERTIFICATION_DATE DATETIME2(7) NULL
AS
BEGIN
	UPDATE ISO.CERTIFICATION SET 
	 CERTIFICATION_NAME = @CERTIFICATION_NAME,CERTIFICACION_DATE = @CERTIFICATION_DATE, 
	 UPDATEDATE =  GETDATE()
	WHERE IDCERTIFICATION = @IDCERTIFICATION

	SELECT * , (SELECT TOP(1) H.PERSONCHANGE FROM HIS.HISTORIAL H WHERE IDMODULE = C.IDCERTIFICATION ORDER BY DATEHISTORY DESC) as PERSONCHANGE
	FROM ISO.CERTIFICATION C WHERE IDCERTIFICATION = @IDCERTIFICATION
END
GO

-- %% [markdown]
-- # [ISO].[SP_UPDATE_FLAG]

-- %%
/****** Object:  StoredProcedure [ISO].[SP_UPDATE_FLAG]    Script Date: 4/3/2024 8:42:49 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
-- =============================================
-- Author:		<Author,,Name>
-- Create date: <Create Date,,>
-- Description:	<Description,,>
-- =============================================
CREATE PROCEDURE [ISO].[SP_UPDATE_FLAG]
	-- Add the parameters for the stored procedure here
	@IDFLAGS VARCHAR(15) NULL,
	@IDRULE VARCHAR(15) NULL,
	@FLAGNAME VARCHAR(150) NULL
AS
BEGIN
	UPDATE ISO.FLAGS SET 
	 IDRULE = @IDRULE, FLAGNAME = @FLAGNAME,
	UPDATEDATE = GETDATE()
	WHERE IDFLAG = @IDFLAGS

	SELECT * , (SELECT TOP(1) H.PERSONCHANGE FROM HIS.HISTORIAL H WHERE IDMODULE = F.IDFLAG ORDER BY DATEHISTORY DESC) as PERSONCHANGE 
	FROM ISO.FLAGS F, ISO.ISORULE I WHERE F.IDRULE = I.IDRULE AND  IDFLAG = @IDFLAGS
END
GO

-- %% [markdown]
-- # [ISO].[SP_UPDATE_ISORULE]

-- %%
/****** Object:  StoredProcedure [ISO].[SP_UPDATE_ISORULE]    Script Date: 4/3/2024 8:42:49 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
-- =============================================
-- Author:		<Author,,Name>
-- Create date: <Create Date,,>
-- Description:	<Description,,>
-- =============================================
CREATE PROCEDURE [ISO].[SP_UPDATE_ISORULE]
	-- Add the parameters for the stored procedure here
	@IDRULE VARCHAR(15) NULL,
	@IDCERTIFICATION VARCHAR(15) NULL,
	@IDAUDIT VARCHAR(15) NULL, 
	@NAMERULE VARCHAR(50) NULL, 
	@RULE_DESCRIPTION VARCHAR(MAX) NULL
AS
BEGIN
	UPDATE ISO.ISORULE SET 
	 IDCERTIFICATION = @IDCERTIFICATION, IDAUDIT = @IDAUDIT,
	 NAMERULE = @NAMERULE,  RULE_DESCRIPTION =  @RULE_DESCRIPTION,
	UPDATEDATE = GETDATE()
	WHERE IDRULE = @IDRULE

	SELECT  R.*,(SELECT TOP(1) H.PERSONCHANGE FROM HIS.HISTORIAL H WHERE IDMODULE = R.IDRULE ORDER BY DATEHISTORY DESC) as PERSONCHANGE,C.*,A.*
	FROM ISO.ISORULE R, ISO.CERTIFICATION C, ISO.AUDITS A WHERE R.IDAUDIT = A.IDAUDIT AND R.IDCERTIFICATION = C.IDCERTIFICATION and IDRULE = @IDRULE
END
GO

-- %% [markdown]
-- # [ISO].[SP_UPDATE_RISK]

-- %%
/****** Object:  StoredProcedure [ISO].[SP_UPDATE_RISK]    Script Date: 4/3/2024 8:42:49 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
-- =============================================
-- Author:		<Author,,Name>
-- Create date: <Create Date,,>
-- Description:	<Description,,>
-- =============================================
CREATE PROCEDURE [ISO].[SP_UPDATE_RISK]
	-- Add the parameters for the stored procedure here
	@IDRISKS VARCHAR(15) NULL,
	@IDRULE VARCHAR(15) NULL,
	@NAMERISKS VARCHAR(50)NULL,
	@ORIGEN VARCHAR(50) NULL, 
	@CONSEQUENSE VARCHAR(500) NULL, 
	@SOURCE_RISK VARCHAR(100) NULL,
	@STATE BIT NULL
AS
BEGIN
	UPDATE ISO.RISKS SET 
	 IDRULE = @IDRULE ,NAMERISKS = @NAMERISKS, ORIGEN = @ORIGEN, CONSEQUENSE = @CONSEQUENSE, SOURCE_RISK = @SOURCE_RISK,
	 STATE=@STATE,
	UPDATEDATE = GETDATE()
	WHERE IDRISKS =  @IDRISKS

	SELECT * FROM ISO.RISKS R, ISO.ISORULE IR WHERE R.IDRULE = IR.IDRULE  AND R.IDRISKS =  @IDRISKS
END
GO

-- %% [markdown]
-- # [ISO].[SP_UPDATE_TASK]

-- %%
/****** Object:  StoredProcedure [ISO].[SP_UPDATE_TASK]    Script Date: 4/3/2024 8:42:49 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
-- =============================================
-- Author:		<Author,,Name>
-- Create date: <Create Date,,>
-- Description:	<Description,,>
-- =============================================
CREATE PROCEDURE [ISO].[SP_UPDATE_TASK]
	-- Add the parameters for the stored procedure here
	@IDTASK VARCHAR(15) NULL,
	@IDRULE VARCHAR(15) NULL,
	@IDUSER VARCHAR(15) NULL,
	@IDFLAGS VARCHAR(15) NULL,
	@PROJECT VARCHAR(100)NULL,
	@EVENT_TASK VARCHAR(500) NULL
AS
BEGIN
	UPDATE ISO.TASKS SET 
	 IDRULE = @IDRULE, IDUSER = @IDUSER, IDFLAG = @IDFLAGS, PROJECT = @PROJECT, EVENT_TASK = @EVENT_TASK,
	UPDATEDATE = GETDATE()
	WHERE IDTASK = @IDTASK

	SELECT * FROM ISO.TASKS T, ISO.ISORULE R, ISO.FLAGS F, US.USERS U WHERE T.IDFLAG= F.IDFLAG AND T.IDUSER = U.IDUSER
	AND T.IDRULE = R.IDRULE AND T.IDTASK = @IDTASK
END
GO

-- %% [markdown]
-- # [ORG].[SP_ADD_COMPANY_POSITION]

-- %%
/****** Object:  StoredProcedure [ORG].[SP_ADD_COMPANY_POSITION]    Script Date: 4/3/2024 8:42:49 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
-- =============================================
-- Author:		<Author,,Name>
-- Create date: <Create Date,,>
-- Description:	<Description,,>
-- =============================================
CREATE PROCEDURE [ORG].[SP_ADD_COMPANY_POSITION]
	-- Add the parameters for the stored procedure here
	@IDUSER VARCHAR(15) NULL, 
	@IDPROCESS VARCHAR(15) NULL, 
	@MANDATED VARCHAR(50) NULL, 
	@DESCRIPTION VARCHAR(1500) NULL,
	@RESPONSABILITIES VARCHAR(50) NULL, 
	@PROFILE_POSITION VARCHAR(50) NULL

AS
BEGIN
	DECLARE @COUNTER_ID INT,
	@ID_COMPANYPOSITION  VARCHAR(15),
		@LASTCODE VARCHAR(15),
		@COUNTER INT,
		@SPLIT_COUNTER INT = 0


	SET @COUNTER_ID = (SELECT COUNT(*) FROM ORG.COMPANY_POSITION)

	IF(@COUNTER_ID<10)
	BEGIN
	--OBTENEMOS EL CODIGO MINIMO DE LA TABLA
           SET @LASTCODE = (SELECT RIGHT(MAX(IDCOMPANY_POSITION),1) FROM ORG.COMPANY_POSITION) 
		   SET @SPLIT_COUNTER = 1
		 END
            ELSE IF (@COUNTER <100) 
			BEGIN
                SET @LASTCODE = (SELECT RIGHT(MAX(IDCOMPANY_POSITION),2) FROM ORG.COMPANY_POSITION) 
				SET @SPLIT_COUNTER = 2
			END
                ELSE IF(@COUNTER <1000)
				BEGIN
                    SET @LASTCODE = (SELECT RIGHT(MAX(IDCOMPANY_POSITION),3) FROM ORG.COMPANY_POSITION) 
					SET @SPLIT_COUNTER = 3
                END

SET @COUNTER = (SELECT COUNT(*)+1 FROM ORG.COMPANY_POSITION)
	
	SET @ID_COMPANYPOSITION = ORG.[GET_CODE_COMPANY](@COUNTER)

	--COMPARAMOS EL ULTIMO DIGITO DE LA TABLA 
	IF @LASTCODE = RIGHT(@ID_COMPANYPOSITION,@SPLIT_COUNTER)
	BEGIN 
	SET @LASTCODE = @LASTCODE + 1
	SET @COUNTER = @LASTCODE
	SET @ID_COMPANYPOSITION = ORG.[GET_CODE_COMPANY](@COUNTER)
	END
	-- SET NOCOUNT ON added to prevent extra result sets from
	-- interfering with SELECT statements.
	SET NOCOUNT ON;
	INSERT INTO ORG.COMPANY_POSITION (IDCOMPANY_POSITION, IDUSER, IDPROCESS, MANDATED, DESCRIPTION, RESPONSABILITIES, PROFILE_POSITION, CREATEDATE, UPDATEDATE)
	VALUES (@ID_COMPANYPOSITION, @IDUSER, @IDPROCESS, @MANDATED, @DESCRIPTION, @RESPONSABILITIES, @PROFILE_POSITION, GETDATE(), NULL )
    -- Insert statements for procedure here
	SELECT * FROM ORG.COMPANY_POSITION CP, US.USERS U, PRO.PROCESS P 
	WHERE CP.IDPROCESS =  P.IDPROCESS AND CP.IDUSER =  U.IDUSER AND 
	CP.IDCOMPANY_POSITION =  @ID_COMPANYPOSITION
END
GO

-- %% [markdown]
-- # [ORG].[SP_GET_ALL_COMPANY_POSITION]

-- %%
/****** Object:  StoredProcedure [ORG].[SP_GET_ALL_COMPANY_POSITION]    Script Date: 4/3/2024 8:42:49 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
-- =============================================
-- Author:		<Author,,Name>
-- Create date: <Create Date,,>
-- Description:	<Description,,>
-- =============================================
CREATE PROCEDURE [ORG].[SP_GET_ALL_COMPANY_POSITION]
	
AS
BEGIN
	SELECT * FROM ORG.COMPANY_POSITION CP, US.USERS U, PRO.PROCESS P WHERE 
	CP.IDUSER =  U.IDUSER AND CP.IDPROCESS =  P.IDPROCESS 
END
GO

-- %% [markdown]
-- # [ORG].[SP_GET_POSITION_BY_ID]

-- %%
/****** Object:  StoredProcedure [ORG].[SP_GET_POSITION_BY_ID]    Script Date: 4/3/2024 8:42:49 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
-- =============================================
-- Author:		<Author,,Name>
-- Create date: <Create Date,,>
-- Description:	<Description,,>
-- =============================================
CREATE PROCEDURE [ORG].[SP_GET_POSITION_BY_ID]
	-- Add the parameters for the stored procedure here
	@IDCOMPANY_POSITION VARCHAR(15) NULL
AS
BEGIN
	SELECT * FROM ORG.COMPANY_POSITION CP, US.USERS U, PRO.PROCESS P WHERE 
	CP.IDUSER =  U.IDUSER AND CP.IDPROCESS =  P.IDPROCESS  AND CP.IDCOMPANY_POSITION = @IDCOMPANY_POSITION
END
GO

-- %% [markdown]
-- # [ORG].[SP_REMOVE_COMPANY_POSITION]

-- %%
/****** Object:  StoredProcedure [ORG].[SP_REMOVE_COMPANY_POSITION]    Script Date: 4/3/2024 8:42:49 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
-- =============================================
-- Author:		<Author,,Name>
-- Create date: <Create Date,,>
-- Description:	<Description,,>
-- =============================================
CREATE PROCEDURE [ORG].[SP_REMOVE_COMPANY_POSITION]
	-- Add the parameters for the stored procedure here
	@IDCOMPANY_POSITION VARCHAR(15) NULL
AS
BEGIN
	
	SELECT * FROM ORG.COMPANY_POSITION CP, US.USERS U, PRO.PROCESS P WHERE 
	CP.IDUSER =  U.IDUSER AND CP.IDPROCESS =  P.IDPROCESS  AND CP.IDCOMPANY_POSITION = @IDCOMPANY_POSITION

	DELETE FROM ORG.COMPANY_POSITION  WHERE IDCOMPANY_POSITION =  @IDCOMPANY_POSITION
END
GO

-- %% [markdown]
-- # [ORG].[SP_UPDATE_COMPANY_POSITION]

-- %%
/****** Object:  StoredProcedure [ORG].[SP_UPDATE_COMPANY_POSITION]    Script Date: 4/3/2024 8:42:49 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
-- =============================================
-- Author:		<Author,,Name>
-- Create date: <Create Date,,>
-- Description:	<Description,,>
-- =============================================
CREATE PROCEDURE [ORG].[SP_UPDATE_COMPANY_POSITION]
	-- Add the parameters for the stored procedure here
	@IDCOMPANY_POSITION VARCHAR(15) NULL,
	@IDUSER VARCHAR(15) NULL,
	@IDPROCESS VARCHAR(15) NULL,
	@MANDATED VARCHAR(50) NULL, 
	@DESCRIPTION VARCHAR(1500) NULL, 
	@RESPONSABILITIES VARCHAR(50) NULL, 
	@PROFILE_POSITION VARCHAR(15) NULL, 
	@TASK_POSITION VARCHAR(15) NULL
AS
BEGIN
	UPDATE ORG.COMPANY_POSITION SET 
	IDUSER = @IDUSER, IDPROCESS = @IDPROCESS, MANDATED = @MANDATED, DESCRIPTION = @DESCRIPTION, 
	RESPONSABILITIES= @RESPONSABILITIES, PROFILE_POSITION = @PROFILE_POSITION,
	UPDATEDATE = GETDATE()
	WHERE IDCOMPANY_POSITION = @IDCOMPANY_POSITION

	SELECT * FROM ORG.COMPANY_POSITION CP, US.USERS U, PRO.PROCESS P WHERE 
	CP.IDUSER =  U.IDUSER AND CP.IDPROCESS =  P.IDPROCESS and IDCOMPANY_POSITION = @IDCOMPANY_POSITION
END
GO

-- %% [markdown]
-- # [PRO].[SP_ADD_NO_ACCORDANCE]

-- %%
/****** Object:  StoredProcedure [PRO].[SP_ADD_NO_ACCORDANCE]    Script Date: 4/3/2024 8:42:49 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
-- =============================================
-- Author:		<Author,,Name>
-- Create date: <Create Date,,>
-- Description:	<Description,,>
-- =============================================
CREATE PROCEDURE [PRO].[SP_ADD_NO_ACCORDANCE]
	-- Add the parameters for the stored procedure here
	@IDPROCESS VARCHAR(15) NULL,
	@IDAUDIT VARCHAR(15) NULL,
	@IDTASK VARCHAR(15) NULL,
	@NAME_NO_ACCORDANCE VARCHAR(50)NULL,
	@KIND VARCHAR(30) NULL, 
	@RANKING VARCHAR(15) NULL,
	@AUDIT_DETECT VARCHAR(MAX) NULL,
	@DESCRIPTON VARCHAR(500) NULL
AS
BEGIN
	DECLARE @COUNTER_ID INT,
	@IDNO_ACCORDANCE VARCHAR(15),
		@LASTCODE VARCHAR(15),
		@COUNTER INT,
		@SPLIT_COUNTER INT = 0


	--SET @COUNTER_ID = (SELECT COUNT(*) FROM pro.NO_ACCORDANCE)

	--IF(@COUNTER_ID<10)
	--BEGIN
	----OBTENEMOS EL CODIGO MINIMO DE LA TABLA
 --          SET @LASTCODE = (SELECT RIGHT(MAX(IDACCORDANCE),1) FROM PRO.NO_ACCORDANCE) 
	--	   SET @SPLIT_COUNTER = 1
	--	 END
 --           ELSE IF (@COUNTER <100) 
	--		BEGIN
 --               SET @LASTCODE = (SELECT RIGHT(MAX(IDACCORDANCE),2) FROM PRO.NO_ACCORDANCE) 
	--			SET @SPLIT_COUNTER = 2
	--		END
 --               ELSE IF(@COUNTER <1000)
	--			BEGIN
 --                   SET @LASTCODE = (SELECT RIGHT(MAX(IDACCORDANCE),3) FROM PRO.NO_ACCORDANCE) 
	--				SET @SPLIT_COUNTER = 3
 --               END

SET @COUNTER = (SELECT COUNT(*)+1 FROM pro.NO_ACCORDANCE)
	
	SET @IDNO_ACCORDANCE = PRO.[GET_CODE_NO_ACCORDANCE](@COUNTER)

	--COMPARAMOS EL ULTIMO DIGITO DE LA TABLA 
	--IF @LASTCODE = RIGHT(@IDNO_ACCORDANCE,@SPLIT_COUNTER)
	--BEGIN 
	--SET @LASTCODE = @LASTCODE + 1
	--SET @COUNTER = @LASTCODE
	--SET @IDNO_ACCORDANCE = PRO.[GET_CODE_NO_ACCORDANCE](@COUNTER)
	--END
	-- SET NOCOUNT ON added to prevent extra result sets from
	-- interfering with SELECT statements.
	SET NOCOUNT ON;

    INSERT INTO PRO.NO_ACCORDANCE(IDACCORDANCE,IDPROCESS,IDAUDIT,IDTASK,NAME_NO_ACCORDANCE,KIND,RANKING,DESCRIPTION,STATE,AUDIT_DETECT,CREATEDATE, UPDATEDATE)
	VALUES (@IDNO_ACCORDANCE,@IDPROCESS,@IDAUDIT, @IDTASK, @NAME_NO_ACCORDANCE, @KIND, @RANKING, @DESCRIPTON,1,@AUDIT_DETECT, GETDATE(), NULL)

	SELECT * FROM PRO.NO_ACCORDANCE NA, PRO.PROCESS P, ISO.AUDITS A , ISO.TASKS T WHERE NA.IDPROCESS =  P.IDPROCESS AND NA.IDAUDIT =  A.IDAUDIT 
	AND NA.IDTASK =  T.IDTASK AND  NA.IDACCORDANCE =  @IDNO_ACCORDANCE
END
GO

-- %% [markdown]
-- # [PRO].[SP_ADD_PROCESS]

-- %%
/****** Object:  StoredProcedure [PRO].[SP_ADD_PROCESS]    Script Date: 4/3/2024 8:42:49 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
-- =============================================
-- Author:		<Author,,Name>
-- Create date: <Create Date,,>
-- Description:	<Description,,>
-- =============================================
CREATE PROCEDURE [PRO].[SP_ADD_PROCESS]
	-- Add the parameters for the stored procedure here
	@IDRULE VARCHAR(15) NULL,
	@PROCESSNAME VARCHAR(50) NULL,
	@CHARGE_PERSON VARCHAR(50) NULL, 
	@ROLE_INVOLVES VARCHAR(15) NULL
AS
BEGIN
	DECLARE @COUNTER_ID INT,
	@IDPROCESS VARCHAR(15),
		@LASTCODE VARCHAR(15),
		@COUNTER INT,
		@SPLIT_COUNTER INT = 0


	--SET @COUNTER_ID = (SELECT COUNT(*) FROM PRO.PROCESS)

	--IF(@COUNTER_ID<10)
	--BEGIN
	----OBTENEMOS EL CODIGO MINIMO DE LA TABLA
 --          SET @LASTCODE = (SELECT RIGHT(MAX(IDPROCESS),1) FROM PRO.PROCESS) 
	--	   SET @SPLIT_COUNTER = 1
	--	 END
 --           ELSE IF (@COUNTER <100) 
	--		BEGIN
 --               SET @LASTCODE = (SELECT RIGHT(MAX(IDPROCESS),2) FROM PRO.PROCESS) 
	--			SET @SPLIT_COUNTER = 2
	--		END
 --               ELSE IF(@COUNTER <1000)
	--			BEGIN
 --                   SET @LASTCODE = (SELECT RIGHT(MAX(IDPROCESS),3) FROM PRO.PROCESS) 
	--				SET @SPLIT_COUNTER = 3
 --               END

SET @COUNTER = (SELECT COUNT(*)+1 FROM PRO.PROCESS)
	
	SET @IDPROCESS = PRO.[GET_CODE_PROCESS](@COUNTER)

	--COMPARAMOS EL ULTIMO DIGITO DE LA TABLA 
	--IF @LASTCODE = RIGHT(@IDPROCESS,@SPLIT_COUNTER)
	--BEGIN 
	--SET @LASTCODE = @LASTCODE + 1
	--SET @COUNTER = @LASTCODE
	--SET @IDPROCESS = PRO.[GET_CODE_PROCESS](@COUNTER)
	--END
	-- SET NOCOUNT ON added to prevent extra result sets from
	-- interfering with SELECT statements.
	SET NOCOUNT ON;

    INSERT INTO PRO.PROCESS(IDPROCESS, IDRULE, PROCESSNAME ,CHARGE_PERSON,ROLE_INVOLVES, CREATEDATE, UPDATEDATE)
	VALUES (@IDPROCESS,@IDRULE,@PROCESSNAME,@CHARGE_PERSON,@ROLE_INVOLVES, GETDATE(), NULL)

	SELECT * FROM PRO.PROCESS P, ISO.ISORULE R WHERE P.IDRULE = R.IDRULE  
END
GO

-- %% [markdown]
-- # [PRO].[SP_GET_ALL_NO_ACCORDANCE]

-- %%
/****** Object:  StoredProcedure [PRO].[SP_GET_ALL_NO_ACCORDANCE]    Script Date: 4/3/2024 8:42:49 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
-- =============================================
-- Author:		<Author,,Name>
-- Create date: <Create Date,,>
-- Description:	<Description,,>
-- =============================================
CREATE PROCEDURE [PRO].[SP_GET_ALL_NO_ACCORDANCE]
	
AS
BEGIN
		SELECT NA.*,(SELECT COUNT(*) FROM AUD.FILES WHERE IDMODULE = NA.IDACCORDANCE) QUANTITY, A.*, T.*
		FROM PRO.NO_ACCORDANCE NA, PRO.PROCESS P, ISO.AUDITS A , ISO.TASKS T WHERE NA.IDPROCESS =  P.IDPROCESS AND NA.IDAUDIT =  A.IDAUDIT 
	AND NA.IDTASK =  T.IDTASK 
END
GO

-- %% [markdown]
-- # [PRO].[SP_GET_ALL_PROCESS]

-- %%
/****** Object:  StoredProcedure [PRO].[SP_GET_ALL_PROCESS]    Script Date: 4/3/2024 8:42:49 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
-- =============================================
-- Author:		<Author,,Name>
-- Create date: <Create Date,,>
-- Description:	<Description,,>
-- =============================================
CREATE PROCEDURE [PRO].[SP_GET_ALL_PROCESS]
	
AS
BEGIN
	SELECT P.*, (SELECT TOP(1) H.PERSONCHANGE FROM HIS.HISTORIAL H WHERE IDMODULE = P.IDPROCESS ORDER BY DATEHISTORY DESC) as PERSONCHANGE,R.* FROM PRO.PROCESS P, ISO.ISORULE R WHERE P.IDRULE = R.IDRULE   
END
GO

-- %% [markdown]
-- # [PRO].[SP_GET_NO_ACCORDANCE_BY_ID]

-- %%
/****** Object:  StoredProcedure [PRO].[SP_GET_NO_ACCORDANCE_BY_ID]    Script Date: 4/3/2024 8:42:49 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
-- =============================================
-- Author:		<Author,,Name>
-- Create date: <Create Date,,>
-- Description:	<Description,,>
-- =============================================
CREATE PROCEDURE [PRO].[SP_GET_NO_ACCORDANCE_BY_ID]
	-- Add the parameters for the stored procedure here
	@IDACCORDANCE VARCHAR(15) NULL
AS
BEGIN
		SELECT * FROM PRO.NO_ACCORDANCE NA, PRO.PROCESS P, ISO.AUDITS A , ISO.TASKS T WHERE NA.IDPROCESS =  P.IDPROCESS AND NA.IDAUDIT =  A.IDAUDIT 
	AND NA.IDTASK =  T.IDTASK AND  NA.IDACCORDANCE = @IDACCORDANCE
END
GO

-- %% [markdown]
-- # [PRO].[SP_GET_PROCESS_BY_ID]

-- %%
/****** Object:  StoredProcedure [PRO].[SP_GET_PROCESS_BY_ID]    Script Date: 4/3/2024 8:42:49 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
-- =============================================
-- Author:		<Author,,Name>
-- Create date: <Create Date,,>
-- Description:	<Description,,>
-- =============================================
CREATE PROCEDURE [PRO].[SP_GET_PROCESS_BY_ID]
	-- Add the parameters for the stored procedure here
	@IDPROCESS VARCHAR(15) NULL
AS
BEGIN
	SELECT P.*, (SELECT TOP(1) H.PERSONCHANGE FROM HIS.HISTORIAL H WHERE IDMODULE = P.IDPROCESS ORDER BY DATEHISTORY DESC) as PERSONCHANGE,R.*
	FROM PRO.PROCESS P, ISO.ISORULE R WHERE P.IDRULE = R.IDRULE AND P.IDPROCESS = @IDPROCESS  
END
GO

-- %% [markdown]
-- # [PRO].[SP_REMOVE_NO_ACCORDANCE]

-- %%
/****** Object:  StoredProcedure [PRO].[SP_REMOVE_NO_ACCORDANCE]    Script Date: 4/3/2024 8:42:49 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
-- =============================================
-- Author:		<Author,,Name>
-- Create date: <Create Date,,>
-- Description:	<Description,,>
-- =============================================
CREATE PROCEDURE [PRO].[SP_REMOVE_NO_ACCORDANCE]
	-- Add the parameters for the stored procedure here
	@IDACCORDANCE VARCHAR(15) NULL
AS
BEGIN
	
		SELECT * FROM PRO.NO_ACCORDANCE NA, PRO.PROCESS P, ISO.AUDITS A , ISO.TASKS T WHERE NA.IDPROCESS =  P.IDPROCESS AND NA.IDAUDIT =  A.IDAUDIT 
	AND NA.IDTASK =  T.IDTASK AND  NA.IDACCORDANCE = @IDACCORDANCE

	DELETE FROM PRO.NO_ACCORDANCE WHERE IDACCORDANCE = @IDACCORDANCE
END
GO

-- %% [markdown]
-- # [PRO].[SP_REMOVE_PROCESS]

-- %%
/****** Object:  StoredProcedure [PRO].[SP_REMOVE_PROCESS]    Script Date: 4/3/2024 8:42:49 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
-- =============================================
-- Author:		<Author,,Name>
-- Create date: <Create Date,,>
-- Description:	<Description,,>
-- =============================================
CREATE PROCEDURE [PRO].[SP_REMOVE_PROCESS]
	-- Add the parameters for the stored procedure here
	@IDPROCESS VARCHAR(15) NULL
AS
BEGIN
	
	SELECT * FROM PRO.PROCESS P, ISO.ISORULE R WHERE P.IDRULE = R.IDRULE AND P.IDPROCESS = @IDPROCESS 

	DELETE FROM PRO.PROCESS WHERE IDPROCESS = @IDPROCESS
END
GO

-- %% [markdown]
-- # [PRO].[SP_UPDATE_NO_ACCORDANCE]

-- %%
/****** Object:  StoredProcedure [PRO].[SP_UPDATE_NO_ACCORDANCE]    Script Date: 4/3/2024 8:42:49 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
-- =============================================
-- Author:		<Author,,Name>
-- Create date: <Create Date,,>
-- Description:	<Description,,>
-- =============================================
CREATE PROCEDURE [PRO].[SP_UPDATE_NO_ACCORDANCE]
	-- Add the parameters for the stored procedure here
	@IDACCORDANCE VARCHAR(15) NULL,
	@IDPROCESS VARCHAR(15) NULL,
	@IDAUDIT VARCHAR(15) NULL,
	@IDTASK VARCHAR(15) NULL,
	@NAME_NO_ACCORDANCE VARCHAR(50)NULL,
	@KIND VARCHAR(30) NULL, 
	@RANKING VARCHAR(15) NULL,
	@AUDIT_DETECT VARCHAR(50) NULL,
	@DESCRIPTON VARCHAR(500) NULL,
	@STATE BIT NULL
AS
BEGIN
	UPDATE PRO.NO_ACCORDANCE SET 
	 IDPROCESS = @IDPROCESS, NAME_NO_ACCORDANCE = @NAME_NO_ACCORDANCE, KIND =  @KIND, IDTASK =  @IDTASK,
	 RANKING = @RANKING, AUDIT_DETECT = @AUDIT_DETECT, @IDAUDIT =  IDAUDIT, DESCRIPTION =  @DESCRIPTON, 
	 STATE =  @STATE, UPDATEDATE = GETDATE()
	WHERE IDACCORDANCE = @IDACCORDANCE

		SELECT * FROM PRO.NO_ACCORDANCE NA, PRO.PROCESS P, ISO.AUDITS A , ISO.TASKS T WHERE NA.IDPROCESS =  P.IDPROCESS AND NA.IDAUDIT =  A.IDAUDIT 
	AND NA.IDTASK =  T.IDTASK AND  NA.IDACCORDANCE = @IDACCORDANCE
END
GO

-- %% [markdown]
-- # [PRO].[SP_UPDATE_PROCESS]

-- %%
/****** Object:  StoredProcedure [PRO].[SP_UPDATE_PROCESS]    Script Date: 4/3/2024 8:42:49 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
-- =============================================
-- Author:		<Author,,Name>
-- Create date: <Create Date,,>
-- Description:	<Description,,>
-- =============================================
CREATE PROCEDURE [PRO].[SP_UPDATE_PROCESS]
	-- Add the parameters for the stored procedure here
	@IDPROCESS VARCHAR(15) NULL,
	@IDRULE VARCHAR(15) NULL,
	@PROCESSNAME VARCHAR(50) NULL,
	@CHARGE_PERSON VARCHAR(50) NULL, 
	@ROLE_INVOLVES VARCHAR(15) NULL
AS
BEGIN
	UPDATE PRO.PROCESS SET 
	 IDPROCESS = @IDPROCESS, IDRULE = @IDRULE, CHARGE_PERSON = @CHARGE_PERSON, 
	 PROCESSNAME = @PROCESSNAME,
	 ROLE_INVOLVES = @ROLE_INVOLVES,
	UPDATEDATE = GETDATE()
	WHERE IDPROCESS =  @IDPROCESS

	SELECT P.*, (SELECT TOP(1) H.PERSONCHANGE FROM HIS.HISTORIAL H WHERE IDMODULE = P.IDPROCESS ORDER BY DATEHISTORY DESC) as PERSONCHANGE,R.*
	FROM PRO.PROCESS P, ISO.ISORULE R WHERE P.IDRULE = R.IDRULE AND IDPROCESS = @IDPROCESS
END
GO

-- %% [markdown]
-- # [US].[ADD_ROLE]

-- %%
/****** Object:  StoredProcedure [US].[ADD_ROLE]    Script Date: 4/3/2024 8:42:49 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
-- =============================================
-- Author:		<Jose Andrey Elizondo Marin>
-- Create date: <12/07/2023,,>
-- Description:	<Obtener los roles>
-- =============================================
CREATE PROCEDURE [US].[ADD_ROLE]
	-- Add the parameters for the stored procedure here
	@ROLE VARCHAR(50)
AS
BEGIN
DECLARE @COUNTER_ID INT,
		@IDROLE VARCHAR(15),
		@LASTCODE VARCHAR(15),
		@COUNTER INT,
		@SPLIT_COUNTER INT = 0


	SET @COUNTER_ID = (SELECT COUNT(*) FROM US.ROLES)

	IF(@COUNTER_ID<10)
	BEGIN
	--OBTENEMOS EL CODIGO MINIMO DE LA TABLA
           SET @LASTCODE = (SELECT RIGHT(MAX(IDROLE),1) FROM US.ROLES) 
		   SET @SPLIT_COUNTER = 1
		 END
            ELSE IF (@COUNTER <100) 
			BEGIN
                SET @LASTCODE = (SELECT RIGHT(MAX(IDROLE),2) FROM US.ROLES) 
				SET @SPLIT_COUNTER = 2
			END
                ELSE IF(@COUNTER <1000)
				BEGIN
                    SET @LASTCODE = (SELECT RIGHT(MAX(IDROLE),3) FROM US.ROLES) 
					SET @SPLIT_COUNTER = 3
                END

SET @COUNTER = (SELECT COUNT(*)+1 FROM US.ROLES)
	
	SET @IDROLE = US.GET_CODE_ROLE(@COUNTER)

	--COMPARAMOS EL ULTIMO DIGITO DE LA TABLA 
	IF @LASTCODE = RIGHT(@IDROLE,@SPLIT_COUNTER)
	BEGIN 
	SET @LASTCODE = @LASTCODE + 1
	SET @COUNTER = @LASTCODE
	SET @IDROLE = US.GET_CODE_ROLE(@COUNTER)
	END
	-- SET NOCOUNT ON added to prevent extra result sets from
	-- interfering with SELECT statements.
	SET NOCOUNT ON;

	INSERT INTO US.ROLES(IDROLE,ROLE,CREATEDATE,UPDATEDATE) 
	VALUES(@IDROLE, @ROLE,GETDATE(), NULL)

    -- Insert statements for procedure here
	SELECT * FROM US.ROLES 
END
GO

-- %% [markdown]
-- # [US].[DELETE_ROLE]

-- %%
/****** Object:  StoredProcedure [US].[DELETE_ROLE]    Script Date: 4/3/2024 8:42:49 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
-- =============================================
-- Author:		<Jose Andrey Elizondo Marin>
-- Create date: <12/07/2023,,>
-- Description:	<Obtener los roles>
-- =============================================
CREATE PROCEDURE [US].[DELETE_ROLE]
	-- Add the parameters for the stored procedure here
	@IDROLE VARCHAR(15)
AS
BEGIN
	-- SET NOCOUNT ON added to prevent extra result sets from
	-- interfering with SELECT statements.
	SET NOCOUNT ON;
	SELECT * FROM US.ROLES  WHERE IDROLE = @IDROLE

	DELETE US.ROLES WHERE IDROLE = @IDROLE

	

    -- Insert statements for procedure here
END
GO

-- %% [markdown]
-- # [US].[GET_ALL_ROLE]

-- %%
/****** Object:  StoredProcedure [US].[GET_ALL_ROLE]    Script Date: 4/3/2024 8:42:49 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
-- =============================================
-- Author:		<Jose Andrey Elizondo Marin>
-- Create date: <12/07/2023,,>
-- Description:	<Obtener los roles>
-- =============================================
CREATE PROCEDURE [US].[GET_ALL_ROLE] 
	-- Add the parameters for the stored procedure here
	
AS
BEGIN
	-- SET NOCOUNT ON added to prevent extra result sets from
	-- interfering with SELECT statements.
	SET NOCOUNT ON;

    -- Insert statements for procedure here
	SELECT *, (SELECT TOP(1) H.PERSONCHANGE FROM HIS.HISTORIAL H WHERE IDMODULE = R.IDROLE ORDER BY DATEHISTORY DESC) as PERSONCHANGE FROM US.ROLES R
END
GO

-- %% [markdown]
-- # [US].[GET_ROLES_BY_ID]

-- %%
/****** Object:  StoredProcedure [US].[GET_ROLES_BY_ID]    Script Date: 4/3/2024 8:42:49 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
-- =============================================
-- Author:		<Jose Andrey Elizondo Marin>
-- Create date: <12/07/2023,,>
-- Description:	<Obtener los roles>
-- =============================================
CREATE PROCEDURE [US].[GET_ROLES_BY_ID] 
	-- Add the parameters for the stored procedure here
	@IDROLE VARCHAR(15)
AS
BEGIN
	-- SET NOCOUNT ON added to prevent extra result sets from
	-- interfering with SELECT statements.
	SET NOCOUNT ON;

    -- Insert statements for procedure here
	SELECT *, (SELECT TOP(1) H.PERSONCHANGE FROM HIS.HISTORIAL H WHERE IDMODULE = R.IDROLE ORDER BY DATEHISTORY DESC) as PERSONCHANGE FROM US.ROLES R WHERE IDROLE = @IDROLE
END
GO

-- %% [markdown]
-- # [US].[SP_ADD_POSITION]

-- %%
/****** Object:  StoredProcedure [US].[SP_ADD_POSITION]    Script Date: 4/3/2024 8:42:49 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
-- =============================================
-- Author:		<Author,,Name>
-- Create date: <Create Date,,>
-- Description:	<Description,,>
-- =============================================
CREATE PROCEDURE [US].[SP_ADD_POSITION]
	-- Add the parameters for the stored procedure here
	@POSITIONJOB VARCHAR(50) NULL,
	@DESCRIPTION VARCHAR(500) NULL,
	@AREA VARCHAR(50) NULL
AS
BEGIN
DECLARE @COUNTER_ID INT,
		@IDPOSITION VARCHAR(15),
		@LASTCODE VARCHAR(15),
		@COUNTER INT,
		@SPLIT_COUNTER INT = 0

		--SET @COUNTER_ID = (SELECT COUNT(*) FROM US.POSITION)

	--IF(@COUNTER_ID<10)
	--BEGIN
	----OBTENEMOS EL CODIGO MINIMO DE LA TABLA
 --          SET @LASTCODE = (SELECT RIGHT(MAX(IDPOSITION),1) FROM US.POSITION) 
	--	   SET @SPLIT_COUNTER = 1
	--	 END
 --           ELSE IF (@COUNTER <100) 
	--		BEGIN
 --               SET @LASTCODE = (SELECT RIGHT(MAX(IDPOSITION),2) FROM US.POSITION) 
	--			SET @SPLIT_COUNTER = 2
	--		END
 --               ELSE IF(@COUNTER <1000)
	--			BEGIN
 --                   SET @LASTCODE = (SELECT RIGHT(MAX(IDPOSITION),3) FROM US.POSITION) 
	--				SET @SPLIT_COUNTER = 3
 --               END

	SET @COUNTER = (SELECT COUNT(*)+1 FROM US.POSITION)
	
	SET @IDPOSITION = US.[GET_CODE_POSITION](@COUNTER)

	--COMPARAMOS EL ULTIMO DIGITO DE LA TABLA 
	--IF @LASTCODE = RIGHT(@IDPOSITION,@SPLIT_COUNTER)
	--BEGIN 
	--SET @LASTCODE = @LASTCODE + 1
	--SET @COUNTER = @LASTCODE
	--SET @IDPOSITION = US.[GET_CODE_POSITION](@COUNTER)
	--END
	-- SET NOCOUNT ON added to prevent extra result sets from
	-- interfering with SELECT statements.
	SET NOCOUNT ON;
    INSERT INTO US.POSITION(IDPOSITION, POSITIONJOB, DESCRIPTION, AREA, CREATEDATE,UPDATEDATE)
	VALUES (@IDPOSITION,@POSITIONJOB,@DESCRIPTION, @AREA, GETDATE(), NULL)

	SELECT * FROM US.POSITION  WHERE  IDPOSITION = @IDPOSITION
END
GO

-- %% [markdown]
-- # [US].[SP_ADD_USER]

-- %%
/****** Object:  StoredProcedure [US].[SP_ADD_USER]    Script Date: 4/3/2024 8:42:49 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
-- =============================================
-- Author:		<Author,,Name>
-- Create date: <Create Date,,>
-- Description:	<Description,,>
-- =============================================
CREATE PROCEDURE [US].[SP_ADD_USER]
	-- Add the parameters for the stored procedure here
	@IDROLE VARCHAR(15) NULL,
	@IDPOSITION VARCHAR(15) NULL,
	@CEDULA VARCHAR(9) NULL,
	@FULLNAME VARCHAR(50) NULL,
	@EMAIL VARCHAR(1500)NULL,
	@PASSWORDHASH VARBINARY(MAX) NULL, 
	@PASSWORDSALT VARBINARY(MAX) NULL
AS
BEGIN
DECLARE @COUNTER_ID INT,
		@IDUSER VARCHAR(15),
		@LASTCODE VARCHAR(15),
		@COUNTER INT,
		@SPLIT_COUNTER INT = 0

	--	SET @COUNTER_ID = (SELECT COUNT(*) FROM US.USERS)

	--IF(@COUNTER_ID<10)
	--BEGIN
	----OBTENEMOS EL CODIGO MINIMO DE LA TABLA
 --          SET @LASTCODE = (SELECT RIGHT(MAX(IDUSER),1) FROM US.USERS) 
	--	   SET @SPLIT_COUNTER = 1
	--	 END
 --           ELSE IF (@COUNTER <100) 
	--		BEGIN
 --               SET @LASTCODE = (SELECT RIGHT(MAX(IDUSER),2) FROM US.USERS) 
	--			SET @SPLIT_COUNTER = 2
	--		END
 --               ELSE IF(@COUNTER <1000)
	--			BEGIN
 --                   SET @LASTCODE = (SELECT RIGHT(MAX(IDUSER),3) FROM US.USERS) 
	--				SET @SPLIT_COUNTER = 3
 --               END

	SET @COUNTER = (SELECT COUNT(*)+1 FROM US.USERS)
	
	SET @IDUSER = US.GET_CODE_USER(@COUNTER)

	--COMPARAMOS EL ULTIMO DIGITO DE LA TABLA 
	--IF @LASTCODE = RIGHT(@IDUSER,@SPLIT_COUNTER)
	--BEGIN 
	--SET @LASTCODE = @LASTCODE + 1
	--SET @COUNTER = @LASTCODE
	--SET @IDUSER = US.GET_CODE_USER(@COUNTER)
	--END
	-- SET NOCOUNT ON added to prevent extra result sets from
	-- interfering with SELECT statements.
	SET NOCOUNT ON;
    INSERT INTO US.USERS(IDUSER,IDROLE,IDPOSITION,CEDULA,FULLNAME,EMAIL,PASSWORDHASH, PASSWORDSALT, ACTIVE, CREATEDATE,UPDATEDATE)
	VALUES (@IDUSER,@IDROLE,@IDPOSITION, @CEDULA,@FULLNAME, @EMAIL, @PASSWORDHASH, @PASSWORDSALT, 1, GETDATE(), NULL)

	SELECT * FROM US.USERS U, US.ROLES R,US.POSITION P  WHERE U.IDROLE =  R.IDROLE AND U.IDPOSITION = P.IDPOSITION  AND IDUSER = @IDUSER
END
GO

-- %% [markdown]
-- # [US].[SP_GET_ALL_POSITION]

-- %%
/****** Object:  StoredProcedure [US].[SP_GET_ALL_POSITION]    Script Date: 4/3/2024 8:42:49 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
-- =============================================
-- Author:		<Author,,Name>
-- Create date: <Create Date,,>
-- Description:	<Description,,>
-- =============================================
CREATE PROCEDURE [US].[SP_GET_ALL_POSITION]
	
AS
BEGIN
	SELECT *,(SELECT TOP(1) H.PERSONCHANGE FROM HIS.HISTORIAL H WHERE IDMODULE = P.IDPOSITION ORDER BY DATEHISTORY DESC) as PERSONCHANGE FROM US.POSITION P 
END
GO

-- %% [markdown]
-- # [US].[SP_GET_ALL_USERS]

-- %%
/****** Object:  StoredProcedure [US].[SP_GET_ALL_USERS]    Script Date: 4/3/2024 8:42:49 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
-- =============================================
-- Author:		<Author,,Name>
-- Create date: <Create Date,,>
-- Description:	<Description,,>
-- =============================================
CREATE PROCEDURE [US].[SP_GET_ALL_USERS]
	
AS
BEGIN
	SELECT U.*,(SELECT TOP(1) H.PERSONCHANGE FROM HIS.HISTORIAL H WHERE IDMODULE = U.IDUSER ORDER BY DATEHISTORY DESC) as CHANGEPERSON,R.*,P.*
	FROM US.USERS U
	INNER  JOIN US.ROLES R ON U.IDROLE =  R.IDROLE 
	INNER  JOIN US.POSITION P ON  U.IDPOSITION = P.IDPOSITION 

END
GO

-- %% [markdown]
-- # [US].[SP_GET_POSITION_BY_ID]

-- %%
/****** Object:  StoredProcedure [US].[SP_GET_POSITION_BY_ID]    Script Date: 4/3/2024 8:42:49 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
-- =============================================
-- Author:		<Author,,Name>
-- Create date: <Create Date,,>
-- Description:	<Description,,>
-- =============================================
CREATE PROCEDURE [US].[SP_GET_POSITION_BY_ID]
	-- Add the parameters for the stored procedure here
	@IDPOSITION VARCHAR(15) NULL
AS
BEGIN
	SELECT *,(SELECT TOP(1) H.PERSONCHANGE FROM HIS.HISTORIAL H WHERE IDMODULE = P.IDPOSITION ORDER BY DATEHISTORY DESC) as PERSONCHANGE FROM US.POSITION P  WHERE  IDPOSITION = @IDPOSITION
END
GO

-- %% [markdown]
-- # [US].[SP_GET_USER_BY_ID]

-- %%
/****** Object:  StoredProcedure [US].[SP_GET_USER_BY_ID]    Script Date: 4/3/2024 8:42:49 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
-- =============================================
-- Author:		<Author,,Name>
-- Create date: <Create Date,,>
-- Description:	<Description,,>
-- =============================================
CREATE PROCEDURE [US].[SP_GET_USER_BY_ID]
	-- Add the parameters for the stored procedure here
	@IDUSER VARCHAR(15) NULL
AS
BEGIN
	SELECT  U.*,(SELECT TOP(1) H.PERSONCHANGE FROM HIS.HISTORIAL H WHERE IDMODULE = U.IDUSER ORDER BY DATEHISTORY DESC) as CHANGEPERSON,R.*,P.*
	FROM US.USERS U, US.ROLES R,US.POSITION P  WHERE U.IDROLE =  R.IDROLE AND U.IDPOSITION = P.IDPOSITION AND U.IDUSER =  @IDUSER
END
GO

-- %% [markdown]
-- # [US].[SP_LOGIN_USERS]

-- %%
/****** Object:  StoredProcedure [US].[SP_LOGIN_USERS]    Script Date: 4/3/2024 8:42:49 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
-- =============================================
-- Author:		<Author,,Name>
-- Create date: <Create Date,,>
-- Description:	<Description,,>
-- =============================================
CREATE PROCEDURE [US].[SP_LOGIN_USERS]
	-- Add the parameters for the stored procedure here
	@EMAIL VARCHAR(1550) NULL
AS
BEGIN
	-- SET NOCOUNT ON added to prevent extra result sets from
	-- interfering with SELECT statements.
	SET NOCOUNT ON;

    -- Insert statements for procedure here
	SELECT * FROM US.USERS U, US.ROLES R,US.POSITION P  WHERE U.IDROLE =  R.IDROLE AND U.IDPOSITION = P.IDPOSITION AND U.EMAIL =  @EMAIL
END
GO

-- %% [markdown]
-- # [US].[SP_REMOVE_POSITION]

-- %%
/****** Object:  StoredProcedure [US].[SP_REMOVE_POSITION]    Script Date: 4/3/2024 8:42:49 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
-- =============================================
-- Author:		<Author,,Name>
-- Create date: <Create Date,,>
-- Description:	<Description,,>
-- =============================================
CREATE PROCEDURE [US].[SP_REMOVE_POSITION]
	-- Add the parameters for the stored procedure here
	@IDPOSITION VARCHAR(15) NULL
AS
BEGIN
	
	SELECT * FROM US.POSITION  WHERE  IDPOSITION = @IDPOSITION

	DELETE FROM US.POSITION WHERE IDPOSITION = @IDPOSITION
END
GO

-- %% [markdown]
-- # [US].[SP_REMOVE_USER]

-- %%
/****** Object:  StoredProcedure [US].[SP_REMOVE_USER]    Script Date: 4/3/2024 8:42:49 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
-- =============================================
-- Author:		<Author,,Name>
-- Create date: <Create Date,,>
-- Description:	<Description,,>
-- =============================================
CREATE PROCEDURE [US].[SP_REMOVE_USER]
	-- Add the parameters for the stored procedure here
	@IDUSER VARCHAR(15) NULL
AS
BEGIN
	
	SELECT * FROM US.USERS U, US.ROLES R WHERE U.IDROLE =  R.IDROLE AND U.IDUSER =  @IDUSER  

	DELETE FROM US.USERS WHERE IDUSER = @IDUSER
END
GO

-- %% [markdown]
-- # [US].[SP_UPDATE_POSITION]

-- %%
/****** Object:  StoredProcedure [US].[SP_UPDATE_POSITION]    Script Date: 4/3/2024 8:42:49 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
-- =============================================
-- Author:		<Author,,Name>
-- Create date: <Create Date,,>
-- Description:	<Description,,>
-- =============================================
CREATE PROCEDURE [US].[SP_UPDATE_POSITION]
	-- Add the parameters for the stored procedure here
	@IDPOSITION VARCHAR(15) NULL,
	@POSITIONJOB VARCHAR(50) NULL,
	@DESCRIPTION VARCHAR(500) NULL,
	@AREA VARCHAR(50) NULL
AS
BEGIN

	
		UPDATE US.POSITION SET 
		POSITIONJOB = @POSITIONJOB, DESCRIPTION =  @DESCRIPTION, AREA= @AREA,
		UPDATEDATE = GETDATE()
		WHERE IDPOSITION = @IDPOSITION

	SELECT *,(SELECT TOP(1) H.PERSONCHANGE FROM HIS.HISTORIAL H WHERE IDMODULE = P.IDPOSITION ORDER BY DATEHISTORY DESC) as PERSONCHANGE FROM US.POSITION P  WHERE  IDPOSITION = @IDPOSITION
END
GO

-- %% [markdown]
-- # [US].[SP_UPDATE_USER]

-- %%
/****** Object:  StoredProcedure [US].[SP_UPDATE_USER]    Script Date: 4/3/2024 8:42:49 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
-- =============================================
-- Author:		<Author,,Name>
-- Create date: <Create Date,,>
-- Description:	<Description,,>
-- =============================================
CREATE PROCEDURE [US].[SP_UPDATE_USER]
	-- Add the parameters for the stored procedure here
	@IDUSER VARCHAR(15) NULL,
	@IDROLE VARCHAR(15) NULL,
	@IDPOSITION VARCHAR(15) NULL, 
	@CEDULA VARCHAR(9) NULL,
	@FULLNAME VARCHAR(50) NULL,
	@EMAIL VARCHAR(1500)NULL,
	@PASSWORDHASH VARBINARY(MAX) NULL, 
	@PASSWORDSALT VARBINARY(MAX) NULL, 
	@ACTIVE BIT NULL
AS
BEGIN

	IF @PASSWORDHASH IS NULL AND @PASSWORDSALT IS NULL
	BEGIN
		UPDATE US.USERS SET 
		 IDROLE = @IDROLE, CEDULA = @CEDULA, EMAIL = @EMAIL, IDPOSITION  =@IDPOSITION,
		 FULLNAME = @FULLNAME, ACTIVE =  @ACTIVE,
		UPDATEDATE = GETDATE()
		WHERE IDUSER = @IDUSER
	END
	ELSE 
	BEGIN 
		UPDATE US.USERS SET 
		 IDROLE = @IDROLE, CEDULA = @CEDULA, EMAIL = @EMAIL,
		 FULLNAME = @FULLNAME, ACTIVE =  @ACTIVE,IDPOSITION  =@IDPOSITION,
		 PASSWORDHASH = @PASSWORDHASH , PASSWORDSALT = @PASSWORDSALT,
		UPDATEDATE = GETDATE()
		WHERE IDUSER = @IDUSER
	END 

	SELECT  U.*,(SELECT TOP(1) H.PERSONCHANGE FROM HIS.HISTORIAL H WHERE IDMODULE = U.IDUSER ORDER BY DATEHISTORY DESC) as CHANGEPERSON,R.*,P.*
	FROM US.USERS U, US.ROLES R,US.POSITION P  WHERE U.IDROLE =  R.IDROLE AND U.IDPOSITION = P.IDPOSITION  AND U.IDUSER =  @IDUSER
END
GO

-- %% [markdown]
-- # [US].[UPDATE_ROLE]

-- %%
/****** Object:  StoredProcedure [US].[UPDATE_ROLE]    Script Date: 4/3/2024 8:42:49 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
-- =============================================
-- Author:		<Jose Andrey Elizondo Marin>
-- Create date: <12/07/2023,,>
-- Description:	<Obtener los roles>
-- =============================================
CREATE PROCEDURE [US].[UPDATE_ROLE]
	-- Add the parameters for the stored procedure here
	@IDROLE VARCHAR(15),
	@ROLE VARCHAR(50)
AS
BEGIN
--DECLARE @PERSONCHANGE VARCHAR(50)
	-- SET NOCOUNT ON added to prevent extra result sets from
	-- interfering with SELECT statements.
	

	--SET @PERSONCHANGE = (SELECT TOP(1) PERSONCHANGE FROM HIS.HISTORIAL WHERE IDMODULE = @IDROLE ORDER BY DATEHISTORY DESC)

	UPDATE US.ROLES SET ROLE = @ROLE, UPDATEDATE= GETDATE()
	WHERE IDROLE = @IDROLE

	SELECT *, (SELECT TOP(1) H.PERSONCHANGE FROM HIS.HISTORIAL H WHERE IDMODULE = R.IDROLE ORDER BY DATEHISTORY DESC) FROM US.ROLES R WHERE IDROLE = @IDROLE
END
GO

-- %% [markdown]
-- # [db_winicg]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [db_winicg] SET  READ_WRITE 
GO
